# %% [markdown]
# > **🌟 Pandas Kütüphanesi 🌟**

# %% [markdown]
# NOT : pandas lambda çalışmalırını incele

# %% [markdown]
# # **1. Bölüm: Giriş İşlemleri**

# %% [markdown]
# ## **▶️▶️ 1.1 Pandas Kütüphanesini Import Etme**

# %% [markdown]
#     Pandas kütüphanesini "pd" olarak import ederiz. Bundan sonra kodlarımız pandas değil pd kısaltması

# %%
import pandas as pd

# %% [markdown]
# ## **▶️▶️ 1.2 Max Column and Max Row Belirleme**

# %% [markdown]
#     Tablolarla çalışırken her run dediğimizde tablonun tüm satır veya tüm sütunlarını görmek istemeyebiliriz. Bu gibi durumlar için aşağıdaki uygulamayı yapabiliriz.
#
#     Çalışacağımız tabloları import etmeden önceden bu ayarı yapmakta fayda var.

# %%
# aşağıdaki örneklerde 85 yerine kaç yazarsak o kadar column veya row getirilir ekrana. Hangisini kullancağımız opsiyonel olduğu hiç kullanmayabiliriz de.

pd.set_option('display.max_columns',5) 
pd.set_option('display.max_rows', 10)

# %% [markdown]
# ## **▶️▶️ 1.3 Hazır Tablo Çekme veya Tablo Oluşturma**

# %% [markdown]
# #### **▶ 3.3.1 Hazır Tablo Çekme**

# %% [markdown]
#     CSV - Comma Seperetad Values
#
#     Şimdilik sadece CSV dosyaları üzerinde çalıştım. CSV dosyalarını "read_csv" metodu ile okuruz.
#
#     okuduğumuz her tablo için Python bir index kolonu ayarlar standart olarak. Ama bazen okuyacağımız tabloda daha uygun bir index kolonumuz olur. Bu gibi durumlarda "index_col" kullanarak kolonumuzu index olarak belirleriz.

# %%
df_survey = pd.read_csv('SOURCES/survey_results_public.csv', index_col = 'Respondent')
df_schema = pd.read_csv('SOURCES/survey_results_schema.csv', index_col = 'Column')

# %% [markdown]
# #### **▶ 3.3.2 Kendi Tablomuzu Oluşturma**

# %% [markdown]
#     Örneğin elimizde "people" isimli bir dictionary olsun. Bu dictionary'i "DataFrame" metodunu kullanarak tablo'ya çevirebilirz.

# %%
people = {
    "first": ["Emre", "İrem", "Süheyla"],
    "last": ["Çakır", "Çukurlu", "Çukurlu"],
    "email": ["emrecakir@gmail.com", "iremcukurlu@email.com", "suheylacukurlu@email.com"]
}

# %%
df_people = pd.DataFrame(people)

# %% [markdown]
# ## **▶️▶️ 1.4 Tablo Gösterimi**

# %% [markdown]
#     Bu bölümde çalışmamın ileriki safhalarında kullanmak üzere oluşturmuş olduğumuz üç farklı tablonun gösterimi yer alacak:

# %%
#1. Tablo: 

df_survey           # Bu tabloda stack owerflow sitesinde yapılan bir survey'in sonuçları yer almaktadır.
# Out:
#        Respondent                                         MainBranch  ...  \
# 0               1             I am a student who is learning to code  ...
# 1               2             I am a student who is learning to code  ...
# 2               3  I am not primarily a developer, but I write co...  ...
# 3               4                     I am a developer by profession  ...
# 4               5                     I am a developer by profession  ...
# ...           ...                                                ...  ...
# 88878       88377                                                NaN  ...
# 88879       88601                                                NaN  ...
# 88880       88802                                                NaN  ...
# 88881       88816                                                NaN  ...
# 88882       88863                                                NaN  ...
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
#2. Tablo:

df_schema           # "df_survey" isimli tablo'da kullanılan column isimlerinin açıklamaları yer almaktadır.
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
#3. Tablo:

df_people           # Bizim oluşturduğumuz 3 farklı kişiye ait isim soyisim ve email adreslerinin yazılı olduğu bir tablo.
# Out:
#      first     last                     email
# 0     Emre    Çakır       emrecakir@gmail.com
# 1     İrem  Çukurlu     iremcukurlu@email.com
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com

# %% [markdown]
# # **2. Bölüm: Gelişmiş İşlemler**

# %% [markdown]
# ## **▶️▶️ 2.1 Column İşlemleri**

# %% [markdown]
# ### **▶ Column Yazdırma**

# %% [markdown]
#     Genel olarak iki şekilde tablonun elemanlarına ulaşırız:
#
#     1. Yöntem: df["Kolon Başlığı"]  : TERCİH EDİLİR.
#
#     2. Yöntem: df.KolonBaşlığı      : İki sebepten dolayı tercih edilmez. Kolon başlıkları metod ismi ile çakışabilir. Ve kolon başlıklarında boşluk olabilir.

# %%
df_people["last"]           # tablomuzun "last" isimli column'una ulaştık ve o kolondaki tüm row'ların çıktısını aldık.
# Out:
# 0      Çakır
# 1    Çukurlu
# 2    Çukurlu
# Name: last, dtype: object

# %%
df_survey["MainBranch"]     # tablomuzun "MainBranch" isimli column'una ulaştık ve o kolondaki tüm row'ların çıktısını aldık.
# Out:
# Respondent
# 1                   I am a student who is learning to code
# 2                   I am a student who is learning to code
# 3        I am not primarily a developer, but I write co...
# 4                           I am a developer by profession
# 5                           I am a developer by profession
#                                ...
# 88377                                                  NaN
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863                                                  NaN
# Name: MainBranch, Length: 88883, dtype: object

# %%
df_schema["QuestionText"]    # tablomuzun "QuestionText" isimli column'una ulaştık ve o kolondaki tüm row'ların çıktısını aldık.
# Out:
# Column
# Respondent      Randomized respondent ID number (not in order ...
# MainBranch      Which of the following options best describes ...
# Hobbyist                                  Do you code as a hobby?
# OpenSourcer           How often do you contribute to open source?
# OpenSource      How do you feel about the quality of open sour...
#                                       ...
# Sexuality       Which of the following do you currently identi...
# Ethnicity       Which of the following do you identify as? Ple...
# Dependents      Do you have any dependents (e.g., children, el...
# SurveyLength    How do you feel about the length of the survey...
# SurveyEase      How easy or difficult was this survey to compl...
# Name: QuestionText, Length: 85, dtype: object

# %% [markdown]
#     Bu metodu bir tablonın kaç tane column'u var veya kaç tane row (etries olarak geçiyor)'u var onu öğrenebiliyoruz. Ayrıca her bir column'a ait hangi data type kullanılmış ve kaç adet row (entries) var onları da görebiliyoruz.

# %%
df_people.info()         # 3 entries: 3 adet row (satır) | 3 columns: 3 adet column (eğer varsa, index column'u hariç)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   3 non-null      object
#  1   last    3 non-null      object
#  2   email   3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %%
df_survey.info()        # 85 entries: 85 adet row (satır) | 1 columns: 1 adet column (eğer varsa, index column'u hariç)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
#  14  YearsCodePro            74331 non-null  object
#  15  CareerSat               72847 non-null  object
#  16  JobSat                  70988 non-null  object
#  17  MgrIdiot                61159 non-null  object
#  18  MgrMoney                61157 non-null  object
#  19  MgrWant                 61232 non-null  object
#  20  JobSeek                 80555 non-null  object
#  21  LastHireDate            79854 non-null  object
#  22  LastInt                 67155 non-null  object
#  23  FizzBuzz                71344 non-null  object
#  24  JobFactors              79371 non-null  object
#  25  ResumeUpdate            77877 non-null  object
#  26  CurrencySymbol          71392 non-null  object
#  27  CurrencyDesc            71392 non-null  object
#  28  CompTotal               55945 non-null  float64
#  29  CompFreq                63268 non-null  object
#  30  ConvertedComp           55823 non-null  float64
#  31  WorkWeekHrs             64503 non-null  float64
#  32  WorkPlan                68914 non-null  object
#  33  WorkChallenge           68141 non-null  object
#  34  WorkRemote              70284 non-null  object
#  35  WorkLoc                 70055 non-null  object
#  36  ImpSyn                  71779 non-null  object
#  37  CodeRev                 70390 non-null  object
#  38  CodeRevHrs              49790 non-null  float64
#  39  UnitTests               62668 non-null  object
#  40  PurchaseHow             61108 non-null  object
#  41  PurchaseWhat            62029 non-null  object
#  42  LanguageWorkedWith      87569 non-null  object
#  43  LanguageDesireNextYear  84088 non-null  object
#  44  DatabaseWorkedWith      76026 non-null  object
#  45  DatabaseDesireNextYear  69147 non-null  object
#  46  PlatformWorkedWith      80714 non-null  object
#  47  PlatformDesireNextYear  77443 non-null  object
#  48  WebFrameWorkedWith      65022 non-null  object
#  49  WebFrameDesireNextYear  62944 non-null  object
#  50  MiscTechWorkedWith      59586 non-null  object
#  51  MiscTechDesireNextYear  64511 non-null  object
#  52  DevEnviron              87317 non-null  object
#  53  OpSys                   87851 non-null  object
#  54  Containers              85366 non-null  object
#  55  BlockchainOrg           48175 non-null  object
#  56  BlockchainIs            60165 non-null  object
#  57  BetterLife              86269 non-null  object
#  58  ITperson                87141 non-null  object
#  59  OffOn                   86663 non-null  object
#  60  SocialMedia             84437 non-null  object
#  61  Extraversion            87305 non-null  object
#  62  ScreenName              80486 non-null  object
#  63  SOVisit1st              83877 non-null  object
#  64  SOVisitFreq             88263 non-null  object
#  65  SOVisitTo               88086 non-null  object
#  66  SOFindAnswer            87816 non-null  object
#  67  SOTimeSaved             86344 non-null  object
#  68  SOHowMuchTime           68378 non-null  object
#  69  SOAccount               87828 non-null  object
#  70  SOPartFreq              74692 non-null  object
#  71  SOJobs                  88066 non-null  object
#  72  EntTeams                87841 non-null  object
#  73  SOComm                  88131 non-null  object
#  74  WelcomeChange           85855 non-null  object
#  75  SONewContent            69560 non-null  object
#  76  Age                     79210 non-null  float64
#  77  Gender                  85406 non-null  object
#  78  Trans                   83607 non-null  object
#  79  Sexuality               76147 non-null  object
#  80  Ethnicity               76668 non-null  object
#  81  Dependents              83059 non-null  object
#  82  SurveyLength            86984 non-null  object
#  83  SurveyEase              87081 non-null  object
# dtypes: float64(5), object(79)
# memory usage: 57.6+ MB

# %%
df_schema.info()        # 88.883 entries: 88.883 adet row (satır) | 84 columns: 84 adet column (eğer varsa, index column'u hariç)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Respondent to SurveyEase
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   QuestionText  85 non-null     object
# dtypes: object(1)
# memory usage: 3.4+ KB

# %% [markdown]
# ### **▶ Column İsmi Değiştirme**

# %%
df_people
# Out:
#      first     last                     email
# 0     Emre    Çakır       emrecakir@gmail.com
# 1     İrem  Çukurlu     iremcukurlu@email.com
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com

# %% [markdown]
#     people isimli tablonun column isimlerini aşağıdaki gibi değiştirebiliriz

# %%
df_people.columns = ['first_name','last_name','email'] 
df_people
# Out:
#   first_name last_name                     email
# 0       Emre     Çakır       emrecakir@gmail.com
# 1       İrem   Çukurlu     iremcukurlu@email.com
# 2    Süheyla   Çukurlu  suheylacukurlu@email.com

# %%
df_people.columns =  [x.upper() for x in df_people.columns] # burada bütün kolon isimlerini büyük harfle yazdırdık.
df_people
# Out:
#   FIRST_NAME LAST_NAME                     EMAIL
# 0       Emre     Çakır       emrecakir@gmail.com
# 1       İrem   Çukurlu     iremcukurlu@email.com
# 2    Süheyla   Çukurlu  suheylacukurlu@email.com

# %%
df_people.columns =  [x.lower() for x in df_people.columns] # burada bütün kolon isimlerini küçük harfle yazdırdık.
df_people
# Out:
#   first_name last_name                     email
# 0       Emre     Çakır       emrecakir@gmail.com
# 1       İrem   Çukurlu     iremcukurlu@email.com
# 2    Süheyla   Çukurlu  suheylacukurlu@email.com

# %%
df_people.columns = df_people.columns.str.replace('_name' , '')  # Burada ise bir nevi first ve last yazmasını sağladık
df_people
# Out:
#      first     last                     email
# 0     Emre    Çakır       emrecakir@gmail.com
# 1     İrem  Çukurlu     iremcukurlu@email.com
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com

# %% [markdown]
#     ÖNEMLİ: Tüm column'ları değiştirmek yerine sadece birkaç tanesini değiştirebiliyoruz:

# %%
df_people.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df = df_people.rename(columns = {'last':'last_name','first':'first_name'})
df
# Out:
#   first_name last_name                     email
# 0       Emre     Çakır       emrecakir@gmail.com
# 1       İrem   Çukurlu     iremcukurlu@email.com
# 2    Süheyla   Çukurlu  suheylacukurlu@email.com

# %%
# eğer df_people tablosunda değişikliğin uygulanmasını istiyorsak:

df_people.rename(columns = {'last':'last_name','first':'first_name'}, inplace=True)
df_people
# Out:
#   first_name last_name                     email
# 0       Emre     Çakır       emrecakir@gmail.com
# 1       İrem   Çukurlu     iremcukurlu@email.com
# 2    Süheyla   Çukurlu  suheylacukurlu@email.com

# %%
df_people.rename(columns={'last_name':'last', 'first_name':'first'}, inplace=True)
df_people
# Out:
#      first     last                     email
# 0     Emre    Çakır       emrecakir@gmail.com
# 1     İrem  Çukurlu     iremcukurlu@email.com
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com

# %% [markdown]
# ### **▶ Column Ekleme**

# %%
df_people['first'] + df_people['last']
# Out:
# 0         EmreÇakır
# 1       İremÇukurlu
# 2    SüheylaÇukurlu
# dtype: object

# %%
df_people['first'] + " " + df_people['last']
# Out:
# 0         Emre Çakır
# 1       İrem Çukurlu
# 2    Süheyla Çukurlu
# dtype: object

# %% [markdown]
#     ÇOK ÖNEMLİ AŞAĞIDAKİ:

# %%
df_people['full_name'] = df_people['first'] + " " + df_people['last']
df_people
# Out:
#      first     last                     email        full_name
# 0     Emre    Çakır       emrecakir@gmail.com       Emre Çakır
# 1     İrem  Çukurlu     iremcukurlu@email.com     İrem Çukurlu
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  Süheyla Çukurlu

# %% [markdown]
# ### **▶ Column Silme**

# %%
df_people['DENEME'] = df_people['email'][0:3]
df_people
# Out:
#      first     last                     email        full_name  \
# 0     Emre    Çakır       emrecakir@gmail.com       Emre Çakır
# 1     İrem  Çukurlu     iremcukurlu@email.com     İrem Çukurlu
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  Süheyla Çukurlu
#
#                      DENEME
# 0       emrecakir@gmail.com
# 1     iremcukurlu@email.com
# 2  suheylacukurlu@email.com

# %%
df_people.drop(columns=['full_name','DENEME'], inplace=True)
df_people
# Out:
#      first     last                     email
# 0     Emre    Çakır       emrecakir@gmail.com
# 1     İrem  Çukurlu     iremcukurlu@email.com
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com

# %%
df_people['email'].str.split('@', expand=True)    # uygulanmadı ana tabloya
# Out:
#                 0          1
# 0       emrecakir  gmail.com
# 1     iremcukurlu  email.com
# 2  suheylacukurlu  email.com

# %%
df_people
# Out:
#      first     last                     email
# 0     Emre    Çakır       emrecakir@gmail.com
# 1     İrem  Çukurlu     iremcukurlu@email.com
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com

# %%
df_people[['new', 'new2']] = df_people['email'].str.split('@', expand=True)
df_people
# Out:
#      first     last                     email             new       new2
# 0     Emre    Çakır       emrecakir@gmail.com       emrecakir  gmail.com
# 1     İrem  Çukurlu     iremcukurlu@email.com     iremcukurlu  email.com
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  suheylacukurlu  email.com

# %%
df_people.drop(columns=['new2'], inplace=True)
df_people
# Out:
#      first     last                     email             new
# 0     Emre    Çakır       emrecakir@gmail.com       emrecakir
# 1     İrem  Çukurlu     iremcukurlu@email.com     iremcukurlu
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  suheylacukurlu

# %% [markdown]
# ### **▶ Column'ların Yerlerini Değiştirme**

# %%
df_people2 = df_people.reindex(columns=['new', 'email', 'first', 'last'])
df_people2
# Out:
#               new                     email    first     last
# 0       emrecakir       emrecakir@gmail.com     Emre    Çakır
# 1     iremcukurlu     iremcukurlu@email.com     İrem  Çukurlu
# 2  suheylacukurlu  suheylacukurlu@email.com  Süheyla  Çukurlu

# %% [markdown]
# ## **▶️▶️ 2.2 Row İşlemleri**

# %% [markdown]
# ### **▶ Row Yazdırma: iloc() ve loc()**

# %% [markdown]
#     loc() ve iloc() metodlarını kullanarak tabloların row'larına ulaşım sağlıyoruz. Örneğin şehirlerin hava durumlarının olduğu bir tabloda 4. row'daki yani satırdaki Manisa'nın cumartesi günü kaç derece olduğunu öğrenebiliriz.

# %% [markdown]
# #### **🗣️ iloc() - _integer location_**

# %% [markdown]
#     Yukarıda bahsedilen tanımı uygularken yalnızca integer kullanılan yöntemdir. Yani location kullanarak bir row'a ulaşacaksan bu row'un kaçıncı indekste olduğunu bilmemiz gerekiyor.

# %%
print(df_people)
# Out:
#      first     last                     email             new
# 0     Emre    Çakır       emrecakir@gmail.com       emrecakir
# 1     İrem  Çukurlu     iremcukurlu@email.com     iremcukurlu
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  suheylacukurlu

# %%
df_survey.head(3)
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 1                      I am a student who is learning to code      Yes  ...
# 2                      I am a student who is learning to code       No  ...
# 3           I am not primarily a developer, but I write co...      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
#
# [3 rows x 84 columns]

# %%
df_schema.head(3)
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?

# %%
# Örneğin aşağıda people isimli tablonun sıfırıncı indexinde yer alan İrem Çukurlu'ya ait tüm bilgiler verilmiştir.

df_people.iloc[1]
# Out:
# first                     İrem
# last                   Çukurlu
# email    iremcukurlu@email.com
# new                iremcukurlu
# Name: 1, dtype: object

# %%
# Örneğin aşağıda survey isimli tabloda yer alan 3. satırdaki kişinin ankette verdiği tüm cevapları yer almaktadır.

df_survey.iloc[3]
# Out:
# MainBranch                         I am a developer by profession
# Hobbyist                                                       No
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
# Employment                                     Employed full-time
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                            White or of European descent
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                                                   Easy
# Name: 4, Length: 84, dtype: object

# %%
# Örneğin schema isimli tabloda 1. indexte yer alan "MainBranch" yer almaktadır.

df_schema.iloc[1]
# Out:
# QuestionText    Which of the following options best describes ...
# Name: MainBranch, dtype: object

# %% [markdown]
#     🔔 iloc() kullanırken integer kullanmak zorunda olduğumuz söyledik. İloc çağırarak elde eltteğimiz veri zerinden başka bilgilere de ulaşmak mümkün elbette. Örneğin son örnekte df_schema'ya ait olan QuestionText karşısında ne yazdığını tam göremiyoruz yerin dar olması sebebiyle. Fakat onu şu şekilde görüntülemek mümkün:

# %%
df_schema.iloc[1]["QuestionText"]
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."'

# %% [markdown]
#     🔔 Burada da survey tablosunda 3. kişiye ait cevaplardan "SurveyLength" isimli bilgiyi yazdıralım:

# %%
df_survey.iloc[3]["SurveyLength"]
# Out:
# 'Appropriate in length'

# %% [markdown]
#     🔔 Ya da people tablosunda 1. satırda yer yalan İrem Çukurlu'nun sadece "email" adresini ekrana getirebiliriz:

# %%
df_people.iloc[1]["email"]
# Out:
# 'iremcukurlu@email.com'

# %% [markdown]
#     🔔🔔 Ayrıca iloc() kullanırken illa tek bir row yani tek bir satır hakkında bilgi yazdırmak zorunda değiliz. Aynı anda birden fazla row yazdırmak mümkün. Ayrıca slicing de yapılabilir.
#
#     Mesela aşağıda survey tablosunda yer alan 3 ve 4. rowları yazdırdık (indexler sıfırdan başlarken "Respondent" isimli column'da 1'den başlıyor. Onu karıştırmamak lazım. iloc() kullanırken index'lere göre hareket edilir)
#
#     Ayrıca dikkat edilmesi gereken ikinci nokta, birden fazla değer girebilmek için parantez içerisinde bir köşeli parantez daha açmaya ihtiyaç duyarız.

# %%
df_survey.iloc[[3, 4]]
# Out:
#                                 MainBranch Hobbyist  ...  \
# Respondent                                           ...
# 4           I am a developer by profession       No  ...
# 5           I am a developer by profession      Yes  ...
#
#                      SurveyLength SurveyEase
# Respondent
# 4           Appropriate in length       Easy
# 5           Appropriate in length       Easy
#
# [2 rows x 84 columns]

# %%
# aşağıda aynı anda 3 eleman görüntüledik:

df_survey.iloc[[3, 4, 7]]
# Out:
#                                 MainBranch Hobbyist  ...  \
# Respondent                                           ...
# 4           I am a developer by profession       No  ...
# 5           I am a developer by profession      Yes  ...
# 8              I code primarily as a hobby      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 8           Appropriate in length  Neither easy nor difficult
#
# [3 rows x 84 columns]

# %%
# aşağıda ise slicing metodunu kullanarak 3 ile 7 arasındaki tüm row'ları yazdırabilriiz:

df_survey.iloc[3:7]
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 4                              I am a developer by profession       No  ...
# 5                              I am a developer by profession      Yes  ...
# 6           I am not primarily a developer, but I write co...      Yes  ...
# 7                              I am a developer by profession       No  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 6                        Too long  Neither easy nor difficult
# 7           Appropriate in length  Neither easy nor difficult
#
# [4 rows x 84 columns]

# %%
df_survey.iloc[1:1000]          # indexler ile "Respondent" karıştırılmasın. iloc ve loc indexleri baz alır.
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 2                      I am a student who is learning to code       No  ...
# 3           I am not primarily a developer, but I write co...      Yes  ...
# 4                              I am a developer by profession       No  ...
# 5                              I am a developer by profession      Yes  ...
# 6           I am not primarily a developer, but I write co...      Yes  ...
# ...                                                       ...      ...  ...
# 999                            I am a developer by profession      Yes  ...
# 1000                           I am a developer by profession      Yes  ...
# 1001                           I am a developer by profession      Yes  ...
# 1002                   I am a student who is learning to code       No  ...
# 1003                              I code primarily as a hobby      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 6                        Too long  Neither easy nor difficult
# ...                           ...                         ...
# 999         Appropriate in length                        Easy
# 1000        Appropriate in length                        Easy
# 1001        Appropriate in length                        Easy
# 1002                     Too long  Neither easy nor difficult
# 1003                     Too long  Neither easy nor difficult
#
# [999 rows x 84 columns]

# %% [markdown]
#     🔔🔔 Ayrıca iloc() kullanarak row'ları yazdırırken işin içine column'ları da dahil edebiliriz:
#
#     Örneğin bir önceki örnekte görültüğü gibi survey isimli tablodaki 16. indexte yer alan kişi  (Respondent: 17) MainBranch'a "I am a developer by profession" diye cevap vermiş. O cevaba basitçe ulabilmek mümkün:

# %%
df_survey.iloc[16, 0]
# Out:
# 'I am a developer by profession'

# %%
df_people
# Out:
#      first     last                     email             new
# 0     Emre    Çakır       emrecakir@gmail.com       emrecakir
# 1     İrem  Çukurlu     iremcukurlu@email.com     iremcukurlu
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  suheylacukurlu

# %%
df_people.iloc[2]
# Out:
# first                     Süheyla
# last                      Çukurlu
# email    suheylacukurlu@email.com
# new                suheylacukurlu
# Name: 2, dtype: object

# %%
# aşağıdaki people tablosunda 2. row'da yer alan süheylanın gmail adresini bulabildik iloc kullanarak.

df_people.iloc[2, 2]
# Out:
# 'suheylacukurlu@email.com'

# %%
df_survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df_survey.iloc[1:100, 11]   # 1'den yüzde kadar olan row'ların 11. column'a verdikleri cevapları yazdırdık
# Out:
# Respondent
# 2      Developer, desktop or enterprise applications;...
# 3      Designer;Developer, back-end;Developer, front-...
# 4                                  Developer, full-stack
# 5      Academic researcher;Developer, desktop or ente...
# 6      Data or business analyst;Data scientist or mac...
#                              ...
# 96     Engineer, data;Engineering manager;Marketing o...
# 97     Data or business analyst;Data scientist or mac...
# 98     Designer;Developer, back-end;Developer, front-...
# 99     Academic researcher;Data or business analyst;D...
# 100    Developer, back-end;Developer, front-end;Devel...
# Name: DevType, Length: 99, dtype: object

# %%
df_survey.iloc[[1, 100], 11]   # Burada ise 1 ve 100. row'ların 11. column'daki karşılığını yadırdık.
# Out:
# Respondent
# 2      Developer, desktop or enterprise applications;...
# 101                                Developer, full-stack
# Name: DevType, dtype: object

# %% [markdown]
#     💠 Alıştırma: yukarıda survey tablosunun tüm column başlıkları yer almaktadır. Öncelikle "Employment" column'unda hangi soruyu sorduklarını yazdır. Ardından da, 100 ile 1000 arasındaki kişilerin bu soruya ne cevap verdiklerini yazdır:
#
#     Not: survey'e ait tüm column'ların ne anlama geldiği schema isimli tabloda yer almaktadır.

# %%
print(df_schema.iloc[5])       # öncelikle bir önceki kod hücresinden Employment'in 5. column'da olduğunu saydım
print("\n📍 Yukarıdaki çıtkı tam olarak okunamadığı için aşağıya daha açık halini bırakıyorum: \n")
print(df_schema.iloc[5]["QuestionText"])
print("\n📍 Aşağıda yer alan tabloda, 100'den 1000'e kadar olan 'Employment' sorusuna verdiği yanıtları görüyoruz.\n")
print(df_survey.iloc[100:1000, 6])
# Out:
# QuestionText    Which of the following best describes your cur...
# Name: Employment, dtype: object
#
# 📍 Yukarıdaki çıtkı tam olarak okunamadığı için aşağıya daha açık halini bırakıyorum:
#
# Which of the following best describes your current employment status?
#
# 📍 Aşağıda yer alan tabloda, 100'den 1000'e kadar olan 'Employment' sorusuna verdiği yanıtları görüyoruz.
#
# Respondent
# 101                 No
# 102                 No
# 103                 No
# 104     Yes, full-time
# 105                 No
#              ...
# 999                 No
# 1000                No
# 1001               NaN
# 1002    Yes, full-time
# 1003    Yes, full-time
# Name: Student, Length: 900, dtype: object

# %% [markdown]
# #### **🗣️ loc() - _location_**

# %% [markdown]
#     iloc() ile biz integer sayıları kullanırdık, loc() ile ise doğrudan ne yazıyorsa onu kullanırız. Örneğin schema tablosunda index'ler string ike survey tablosunda indexler integer'dır. İkisi için loc() kullanırken birinde string diğerinde integer kullanacağız.

# %%
df_schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
# yukarıda görüldüğü gibi index column'unda stringler var. O yüzden string kullanacağız:

df_schema.loc["OpenSourcer"]        # yukarıdaki gibi listeyi gördükten sonra yazdırmak istediğimizi bulmak çok kolay olur.
# Out:
# QuestionText    How often do you contribute to open source?
# Name: OpenSourcer, dtype: object

# %%
df_survey
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 1                      I am a student who is learning to code      Yes  ...
# 2                      I am a student who is learning to code       No  ...
# 3           I am not primarily a developer, but I write co...      Yes  ...
# 4                              I am a developer by profession       No  ...
# 5                              I am a developer by profession      Yes  ...
# ...                                                       ...      ...  ...
# 88377                                                     NaN      Yes  ...
# 88601                                                     NaN       No  ...
# 88802                                                     NaN       No  ...
# 88816                                                     NaN       No  ...
# 88863                                                     NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 88377       Appropriate in length                        Easy
# 88601                         NaN                         NaN
# 88802                         NaN                         NaN
# 88816                         NaN                         NaN
# 88863       Appropriate in length                        Easy
#
# [88883 rows x 84 columns]

# %%
# yukarıda görüldüğü gibi index column'unda integer'lar var. O yüzden integer kullanacağız:

df_survey.loc[3]        # yukarıdaki gibi listeyi gördükten sonra yazdırmak istediğimizi bulmak çok kolay olur.
# Out:
# MainBranch      I am not primarily a developer, but I write co...
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
# Employment                                     Employed full-time
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                    Yes
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 3, Length: 84, dtype: object

# %%
df_people
# Out:
#      first     last                     email             new
# 0     Emre    Çakır       emrecakir@gmail.com       emrecakir
# 1     İrem  Çukurlu     iremcukurlu@email.com     iremcukurlu
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  suheylacukurlu

# %%
# aynı şeklde yukarıda görüldüğü gibi people tablosundaki index'lerde string:

df_people.loc[1]
# Out:
# first                     İrem
# last                   Çukurlu
# email    iremcukurlu@email.com
# new                iremcukurlu
# Name: 1, dtype: object

# %%
df_people.loc[1, "first"]       # 1. row'daki kişiye ait "first" colonunda ne yer alıyor?
# Out:
# 'İrem'

# %%
df_people.iloc[1, 0]            # yukarıda loc metodu ile kurduğumuz yapının çok daha anlamlı olduğu net
# Out:
# 'İrem'

# %%
df_survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df_survey.loc[1:100, 'WorkRemote']      # loc kullanarak anlamlı sonuçlar çıkarmak işte bu kadar kolay.
# Out:
# Respondent
# 1                                                    NaN
# 2                                                    NaN
# 3                       Less than once per month / Never
# 4                       Less than once per month / Never
# 5                                  A few days each month
#                              ...
# 96                                                   NaN
# 97                                 A few days each month
# 98                                                   NaN
# 99                                                   NaN
# 100    All or almost all the time (I'm full-time remote)
# Name: WorkRemote, Length: 100, dtype: object

# %% [markdown]
#     📣 Bir önceki kodu loc() yerine iloc() ile yazdırmaya kalksaydık, öncelikle 'WorkRemote' isimli kolonunun kaçıncı sırada olduğunu sayıp ondan sonra yapmamız gerekecekti.
#
#     📣 Ayrıca loc() kullanırken de 'WorkRemote' nin karşılığı olan sayıyı yazarsak kabul olmaz. Çünkü column'lar için bir sayı yoktur ama row'lar için bir index sayıları vardır. O yüzden row'lar için integer kullanabilir ama column'lar için kullanamayız.

# %%
print("Aşağıdaki tablo loc[] metodu kullanılarak yazılmıştır. 1'den 100'e kadar olan row'ların 'WorkRemote' ve 'CodeRev' column'ları arasındaki yanıtları yazdırılmıştır. \n")

df_survey.loc[1:100, 'WorkRemote':'CodeRev']
# Out:
# Aşağıdaki tablo loc[] metodu kullanılarak yazılmıştır. 1'den 100'e kadar olan row'ların 'WorkRemote' ve 'CodeRev' column'ları arasındaki yanıtları yazdırılmıştır.
#                                                    WorkRemote WorkLoc  \
# Respondent
# 1                                                         NaN     NaN
# 2                                                         NaN     NaN
# 3                            Less than once per month / Never    Home
# 4                            Less than once per month / Never    Home
# 5                                       A few days each month  Office
# ...                                                       ...     ...
# 96                                                        NaN     NaN
# 97                                      A few days each month  Office
# 98                                                        NaN     NaN
# 99                                                        NaN     NaN
# 100         All or almost all the time (I'm full-time remote)    Home
#
#                             ImpSyn                                  CodeRev
# Respondent
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                          Average                                       No
# 4           A little below average                                       No
# 5           A little above average  Yes, because I see value in code review
# ...                            ...                                      ...
# 96                             NaN                                      NaN
# 97          A little above average  Yes, because I see value in code review
# 98                             NaN                                      NaN
# 99                             NaN                                      NaN
# 100         A little above average  Yes, because I see value in code review
#
# [100 rows x 4 columns]

# %% [markdown]
# ### **▶ Row Değiştirme**

# %%
df_people
# Out:
#      first     last                     email             new
# 0     Emre    Çakır       emrecakir@gmail.com       emrecakir
# 1     İrem  Çukurlu     iremcukurlu@email.com     iremcukurlu
# 2  Süheyla  Çukurlu  suheylacukurlu@email.com  suheylacukurlu

# %%
df_people.loc[1] = ['İrem Süheyla', 'Çukurlu', 'iremScukurlu@email.com']
df_people.loc[2] = ['Ceren İlayda', 'Çukurlu', 'cerenIcukurlu@email.com']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df_people.loc[1] = ['İrem Süheyla', 'Çukurlu', 'iremScukurlu@email.com']
#       2 df_people.loc[2] = ['Ceren İlayda', 'Çukurlu', 'cerenIcukurlu@email.com']
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:885, in _LocationIndexer.__setitem__(self, key, value)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 885 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1893, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1890 # align and set the values
#    1891 if take_split_path:
#    1892     # We have to operate column-wise
# -> 1893     self._setitem_with_indexer_split_path(indexer, value, name)
#    1894 else:
#    1895     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1978, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1975         self._setitem_single_column(ilocs[0], value, pi)
#    1977     else:
# -> 1978         raise ValueError(
#    1979             "Must have equal len keys and value "
#    1980             "when setting with an iterable"
#    1981         )
#    1983 else:
#    1984     # scalar value
#    1985     for loc in ilocs:
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %% [markdown]
#     İŞTE BU KADAR KOLAY

# %%
df_people
# Out:
#           first     last                    email
# 0          Emre    Çakır      emrecakir@gmail.com
# 1  İrem Süheyla  Çukurlu   iremScukurlu@email.com
# 2  Ceren İlayda  Çukurlu  cerenIcukurlu@email.com

# %% [markdown]
#     ANCAK DAHA DA KOLAYI VAR:
#
#     Eğer 3 tane değil de 100 tane column olsaydı, yukarıdaki yöntem yetersiz kalırdı çünkü bütün column'ları tek tek girmeniz gerekirdi. Ancak aşağıdaki yöntem mükemmel pratik:

# %%
df_people.loc[1 , ['last','email']] = ['Çakır','iremSçakır@email.com']  # işte böyle :)

# %%
df_people
# Out:
#           first     last                    email
# 0          Emre    Çakır      emrecakir@gmail.com
# 1  İrem Süheyla    Çakır     iremSçakır@email.com
# 2  Ceren İlayda  Çukurlu  cerenIcukurlu@email.com

# %%
filt = (df_people['email'] == 'iremSçakır@email.com')
df_people.loc[filt,'last'] = 'Çukurlu' 
# Burada Çakır soysimini Çukurlu ile değiştirmiş olduk.

# %%
df_people
# Out:
#           first     last                    email
# 0          Emre    Çakır      emrecakir@gmail.com
# 1  İrem Süheyla  Çukurlu     iremSçakır@email.com
# 2  Ceren İlayda  Çukurlu  cerenIcukurlu@email.com

# %%
df_people['last'].str.upper() # bütün soyisimleri büyüttük. Ama ana tabloya işlemesi içn bir sonraki hücreye bak.
# Out:
# 0      ÇAKIR
# 1    ÇUKURLU
# 2    ÇUKURLU
# Name: last, dtype: object

# %%
df_people['last'] = df_people['last'].str.upper()
df_people
# Out:
#           first     last                    email
# 0          Emre    ÇAKIR      emrecakir@gmail.com
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com

# %% [markdown]
# ### **▶ Row Ekleme**

# %%
df_people = df_people._append({'first' : 'İrem'}, ignore_index=True)
df_people
# Out:
#           first     last                    email
# 0          Emre    ÇAKIR      emrecakir@gmail.com
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com
# 3          İrem      NaN                      NaN

# %%
df_people.loc[3,['last', 'email', 'new']] = ['Çukurlu', 'iremnew@email.com','iremnew']
df_people
# Out:
# C:\Users\monstr\AppData\Local\Temp\ipykernel_9908\967693319.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'iremnew' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_people.loc[3,['last', 'email', 'new']] = ['Çukurlu', 'iremnew@email.com','iremnew']
#           first     last                    email      new
# 0          Emre    ÇAKIR      emrecakir@gmail.com      NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com      NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com      NaN
# 3          İrem  Çukurlu        iremnew@email.com  iremnew

# %% [markdown]
# ### **▶ Row Silme**

# %%
df_people = df_people.drop(index = 3)

df_people       # 3. index silindi
# Out:
#           first     last                    email  new
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN

# %%
filt = df_people['last'] == 'Çukurlu'
df_people = df_people.drop(index = df_people[filt].index)
df_people
# Out:
#           first     last                    email  new
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN

# %% [markdown]
# ## **▶️▶️ 2.3 Tablo Birleştirme**

# %%
new_people = {
    "first" : ["Hacer",'Halise'],
    "last" : ["Çakır",'Çukurlu'],
    "email" : ["yok",'yok']
}    

df_new_people = pd.DataFrame(new_people)

# %%
df_people = df_people._append(df_new_people, ignore_index=True, sort=False) 
# Burada "sort = False" kısmı ne işe yarıyor ben de anlamadım. Yapmasak da oluyor bizde. 
df_people
# Out:
#           first     last                    email  new
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 3         Hacer    Çakır                      yok  NaN
# 4        Halise  Çukurlu                      yok  NaN

# %% [markdown]
# ## **▶️▶️ 2.4 Filtre Oluşturma Yöntemi**

# %% [markdown]
# #### **▶ a) df_people üzerinde uygulamalar**

# %%
df_people
# Out:
#           first     last                    email  new
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 3         Hacer    Çakır                      yok  NaN
# 4        Halise  Çukurlu                      yok  NaN

# %%
# aşağıda yaptığımız işlem şudur, last == 'Çukurlu' olan row'ları True, geri kalanları ise False yazdır.

filt = df_people["last"] == "Çukurlu"
filt
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: last, dtype: bool

# %% [markdown]
#     Yukarıda uyguladığımız filtre işlemini "filt" değişkenine atadık. filt değişkeni bize soyisimi çukurlu olan satırların True, diğer satırların ise False olduğunu söyler. ana tabloda hiçbir değişiklik yok yani. Eğer biz bu filt değişkenini aşağıdaki gibi bir loc[] metodu içerisine yazarsak, sadece True olan satırlar yazdırılacak. Böylece column'lar üzerinden filtreleme yapıp istediğimiz row'u yazdırabiliyoruz:

# %%
# soyismi "Çukurlu" olan satırları yazdıran filtreleme işlemi:

df_people.loc[filt]
# Out:
#     first     last email  new
# 4  Halise  Çukurlu   yok  NaN

# %%
# soyismi "Çukurlu" olan isimleri yazdıran filtreleme işlemi:

df_people.loc[filt, 'first']
# Out:
# 4    Halise
# Name: first, dtype: object

# %%
# ya da soyisimi "Çukurlu" olan emailleri yazdıran filtrelem işlemi:

df_people.loc[filt, 'email']
# Out:
# 4    yok
# Name: email, dtype: object

# %% [markdown]
# #### **▶ b) df_survey üzerinde uygulamalar**

# %%
df_survey
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 1                      I am a student who is learning to code      Yes  ...
# 2                      I am a student who is learning to code       No  ...
# 3           I am not primarily a developer, but I write co...      Yes  ...
# 4                              I am a developer by profession       No  ...
# 5                              I am a developer by profession      Yes  ...
# ...                                                       ...      ...  ...
# 88377                                                     NaN      Yes  ...
# 88601                                                     NaN       No  ...
# 88802                                                     NaN       No  ...
# 88816                                                     NaN       No  ...
# 88863                                                     NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 88377       Appropriate in length                        Easy
# 88601                         NaN                         NaN
# 88802                         NaN                         NaN
# 88816                         NaN                         NaN
# 88863       Appropriate in length                        Easy
#
# [88883 rows x 84 columns]

# %%
df_survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %% [markdown]
#     Aşağıda kullanılan value_couns() metodunu görmedik daha. Özetle, survey tablosundaki cinsiyet'e verilen cevapları detaylı olarka yazdırmıştır.

# %%
df_survey["Sexuality"].value_counts()
# Out:
# Sexuality
# Straight / Heterosexual                            70155
# Bisexual                                            3440
# Gay or Lesbian                                      1798
# Bisexual;Straight / Heterosexual                     494
# Bisexual;Gay or Lesbian                              114
# Bisexual;Gay or Lesbian;Straight / Heterosexual      108
# Gay or Lesbian;Straight / Heterosexual                38
# Name: count, dtype: int64

# %%
# biz aşağıya, cinsiyetini "bisexual" veya "Gay or Lesbian" olarak belirten kişilerin satırlarını yazdıralım:

filt_sex = (df_survey["Sexuality"] == "Bisexual") | (df_survey["Sexuality"] == "Gay or Lesbian")

df_survey.loc[filt_sex]
# Out:
#                                         MainBranch Hobbyist  ...  \
# Respondent                                                   ...
# 9                   I am a developer by profession      Yes  ...
# 26                  I am a developer by profession      Yes  ...
# 34          I am a student who is learning to code      Yes  ...
# 39                  I am a developer by profession      Yes  ...
# 60                  I am a developer by profession      Yes  ...
# ...                                            ...      ...  ...
# 81093                                          NaN      Yes  ...
# 83397                                          NaN      Yes  ...
# 83612                                          NaN      Yes  ...
# 84539                                          NaN      Yes  ...
# 85961                                          NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 9           Appropriate in length  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 34                      Too short  Neither easy nor difficult
# 39          Appropriate in length                        Easy
# 60                            NaN                         NaN
# ...                           ...                         ...
# 81093       Appropriate in length                        Easy
# 83397       Appropriate in length                        Easy
# 83612                         NaN                         NaN
# 84539       Appropriate in length                        Easy
# 85961       Appropriate in length                   Difficult
#
# [5238 rows x 84 columns]

# %% [markdown]
#     not: yukarıda görüldüğü gibi union simgesi olan | kulanılmıştır.
#
#     union (birleşim)      :     |
#     intersection (kesişim):     &
#     difference (fark)     :     -
#
#     symetricdifference     :    ^

# %%
# aşağıda atık bu cinsiyet filtresine ait bir değişkenimiz var. Ve bu değişken üzerinden daha pratik işlemler yapılabilir

df_survey_sex = df_survey.loc[filt_sex]
df_survey_sex
# Out:
#                                         MainBranch Hobbyist  ...  \
# Respondent                                                   ...
# 9                   I am a developer by profession      Yes  ...
# 26                  I am a developer by profession      Yes  ...
# 34          I am a student who is learning to code      Yes  ...
# 39                  I am a developer by profession      Yes  ...
# 60                  I am a developer by profession      Yes  ...
# ...                                            ...      ...  ...
# 81093                                          NaN      Yes  ...
# 83397                                          NaN      Yes  ...
# 83612                                          NaN      Yes  ...
# 84539                                          NaN      Yes  ...
# 85961                                          NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 9           Appropriate in length  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 34                      Too short  Neither easy nor difficult
# 39          Appropriate in length                        Easy
# 60                            NaN                         NaN
# ...                           ...                         ...
# 81093       Appropriate in length                        Easy
# 83397       Appropriate in length                        Easy
# 83612                         NaN                         NaN
# 84539       Appropriate in length                        Easy
# 85961       Appropriate in length                   Difficult
#
# [5238 rows x 84 columns]

# %%
filt_sex_profession = df_survey_sex["MainBranch"] == "I am a developer by profession"
df_survey_SexPro = df_survey_sex.loc[filt_sex_profession]
df_survey_SexPro
# Out:
#                                 MainBranch Hobbyist  ...  \
# Respondent                                           ...
# 9           I am a developer by profession      Yes  ...
# 26          I am a developer by profession      Yes  ...
# 39          I am a developer by profession      Yes  ...
# 60          I am a developer by profession      Yes  ...
# 100         I am a developer by profession      Yes  ...
# ...                                    ...      ...  ...
# 88800       I am a developer by profession      Yes  ...
# 88845       I am a developer by profession      Yes  ...
# 88865       I am a developer by profession       No  ...
# 88868       I am a developer by profession      Yes  ...
# 88873       I am a developer by profession      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 9           Appropriate in length  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 39          Appropriate in length                        Easy
# 60                            NaN                         NaN
# 100         Appropriate in length                        Easy
# ...                           ...                         ...
# 88800                    Too long  Neither easy nor difficult
# 88845       Appropriate in length                        Easy
# 88865       Appropriate in length                        Easy
# 88868       Appropriate in length                        Easy
# 88873       Appropriate in length                        Easy
#
# [3621 rows x 84 columns]

# %% [markdown]
#     Yukarıdaki tablonun en altında 3.621 rows yazıyor. Yani bizim istediğimiz şartlara uyan 3.621 kişi varmış. Buna shape metodu ile de ulaşılabilir. Aynı şekilde ana tablomuz olan df_survey'e de ulaşılabilir.
#
#     aşağıda sizin için istediğimiz şartları sağlayan kişilerin, toplamda ankete katılan kişilerin yüzde kaçı olduğunu hesaplayacağım:

# %%
rows_sex = df_survey_sex.shape[0]
rows_filter = df_survey_SexPro.shape[0]
rows_nofilter = df_survey.shape[0]

percante = round((rows_filter / rows_nofilter), 2)

print(f"Ankete katılan {rows_sex} kişi ya 'Bisexual' ya da 'Gay or Lesbian' cinsiyetlerine sahipler. Ve bunların da {rows_filter} tanesi, 'I am a develooper by profession' demiştir.")

print(f"Ankete katılan toplam insan sayısı, {rows_nofilter} olduğunda göre: ")

print(f"Ankete katılanların yüzde {percante}'u bizim filtrelerimize uygundur.")
# Out:
# Ankete katılan 5238 kişi ya 'Bisexual' ya da 'Gay or Lesbian' cinsiyetlerine sahipler. Ve bunların da 3621 tanesi, 'I am a develooper by profession' demiştir.
# Ankete katılan toplam insan sayısı, 88883 olduğunda göre:
# Ankete katılanların yüzde 0.04'u bizim filtrelerimize uygundur.

# %% [markdown]
#     Şimdi de başka bir alıştırma yapalım. Biraz inceleyelim öncelikle.

# %%
df_schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
df_schema.loc['YearsCode']['QuestionText']
# Out:
# 'Including any education, how many years have you been coding?'

# %% [markdown]
#     YearsCode'a 5'den fazla cevap verenlerin kaç tanesinde Bechalor's Degree veya Master's Degre yoktur?

# %%
df_survey['YearsCode'].value_counts()
# Out:
# YearsCode
# 5     7047
# 10    6777
# 6     6179
# 4     5729
# 8     5361
#       ...
# 50      51
# 47      36
# 48      31
# 46      27
# 49      25
# Name: count, Length: 52, dtype: int64

# %%
df_survey['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              39134
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           19569
# Some college/university study without earning a degree                                10502
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8642
# Associate degree                                                                       2938
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2432
# Primary/elementary school                                                              1422
# Professional degree (JD, MD, etc.)                                                     1198
# I never completed any formal education                                                  553
# Name: count, dtype: int64

# %%
filt_years = (df_survey['YearsCode'] > "5") & (df_survey['YearsCode'] != "Less than 1 year")    # Less than 1 year bizim düzenimizi bozan bir yanıt olduğu için çıkartıyoruz onur
filt_education = (df_survey['EdLevel'] == "Bachelor’s degree (BA, BS, B.Eng., etc.)") | (df_survey['EdLevel'] == "Master’s degree (MA, MS, M.Eng., MBA, etc.)")

df_years = df_survey.loc[filt_years]

df_final = df_years.loc[~filt_education]        # ÇOK ÖNEMLİ. YUKARIDAKİ filt_education HARİCİNDEKİLERİ SEÇTİK BURADA

ads = df_final[['EdLevel', 'YearsCode']]

ads     # istediğimiz sonucu veren tablo budur
# Out:
#                                                       EdLevel  \
# Respondent
# 27          Some college/university study without earning ...
# 37                                           Associate degree
# 42          Secondary school (e.g. American high school, G...
# 86          Some college/university study without earning ...
# 88          Secondary school (e.g. American high school, G...
# ...                                                       ...
# 72492       Some college/university study without earning ...
# 82789       Secondary school (e.g. American high school, G...
# 83000       Secondary school (e.g. American high school, G...
# 86566       Some college/university study without earning ...
# 88863                      Professional degree (JD, MD, etc.)
#
#                      YearsCode
# Respondent
# 27                           7
# 37                           7
# 42                           8
# 86                           6
# 88                           9
# ...                        ...
# 72492                        7
# 82789                        9
# 83000                        7
# 86566       More than 50 years
# 88863                        8
#
# [6150 rows x 2 columns]

# %%
df_survey
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 1                      I am a student who is learning to code      Yes  ...
# 2                      I am a student who is learning to code       No  ...
# 3           I am not primarily a developer, but I write co...      Yes  ...
# 4                              I am a developer by profession       No  ...
# 5                              I am a developer by profession      Yes  ...
# ...                                                       ...      ...  ...
# 88377                                                     NaN      Yes  ...
# 88601                                                     NaN       No  ...
# 88802                                                     NaN       No  ...
# 88816                                                     NaN       No  ...
# 88863                                                     NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 88377       Appropriate in length                        Easy
# 88601                         NaN                         NaN
# 88802                         NaN                         NaN
# 88816                         NaN                         NaN
# 88863       Appropriate in length                        Easy
#
# [88883 rows x 84 columns]

# %%
df_survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %% [markdown]
#     Aşağıda kullanılan value_couns() metodunu görmedik daha. Özetle, survey tablosundaki cinsiyet'e verilen cevapları detaylı olarka yazdırmıştır.

# %%
df_survey["Sexuality"].value_counts()
# Out:
# Sexuality
# Straight / Heterosexual                            70155
# Bisexual                                            3440
# Gay or Lesbian                                      1798
# Bisexual;Straight / Heterosexual                     494
# Bisexual;Gay or Lesbian                              114
# Bisexual;Gay or Lesbian;Straight / Heterosexual      108
# Gay or Lesbian;Straight / Heterosexual                38
# Name: count, dtype: int64

# %%
# biz aşağıya, cinsiyetini "bisexual" veya "Gay or Lesbian" olarak belirten kişilerin satırlarını yazdıralım:

filt_sex = (df_survey["Sexuality"] == "Bisexual") | (df_survey["Sexuality"] == "Gay or Lesbian")

df_survey.loc[filt_sex]
# Out:
#                                         MainBranch Hobbyist  ...  \
# Respondent                                                   ...
# 9                   I am a developer by profession      Yes  ...
# 26                  I am a developer by profession      Yes  ...
# 34          I am a student who is learning to code      Yes  ...
# 39                  I am a developer by profession      Yes  ...
# 60                  I am a developer by profession      Yes  ...
# ...                                            ...      ...  ...
# 81093                                          NaN      Yes  ...
# 83397                                          NaN      Yes  ...
# 83612                                          NaN      Yes  ...
# 84539                                          NaN      Yes  ...
# 85961                                          NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 9           Appropriate in length  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 34                      Too short  Neither easy nor difficult
# 39          Appropriate in length                        Easy
# 60                            NaN                         NaN
# ...                           ...                         ...
# 81093       Appropriate in length                        Easy
# 83397       Appropriate in length                        Easy
# 83612                         NaN                         NaN
# 84539       Appropriate in length                        Easy
# 85961       Appropriate in length                   Difficult
#
# [5238 rows x 84 columns]

# %% [markdown]
#     not: yukarıda görüldüğü gibi union simgesi olan | kulanılmıştır.
#
#     union (birleşim)      :     |
#     intersection (kesişim):     &
#     difference (fark)     :     -
#
#     symetricdifference     :    ^

# %%
# aşağıda atık bu cinsiyet filtresine ait bir değişkenimiz var. Ve bu değişken üzerinden daha pratik işlemler yapılabilir

df_survey_sex = df_survey.loc[filt_sex]
df_survey_sex
# Out:
#                                         MainBranch Hobbyist  ...  \
# Respondent                                                   ...
# 9                   I am a developer by profession      Yes  ...
# 26                  I am a developer by profession      Yes  ...
# 34          I am a student who is learning to code      Yes  ...
# 39                  I am a developer by profession      Yes  ...
# 60                  I am a developer by profession      Yes  ...
# ...                                            ...      ...  ...
# 81093                                          NaN      Yes  ...
# 83397                                          NaN      Yes  ...
# 83612                                          NaN      Yes  ...
# 84539                                          NaN      Yes  ...
# 85961                                          NaN      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 9           Appropriate in length  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 34                      Too short  Neither easy nor difficult
# 39          Appropriate in length                        Easy
# 60                            NaN                         NaN
# ...                           ...                         ...
# 81093       Appropriate in length                        Easy
# 83397       Appropriate in length                        Easy
# 83612                         NaN                         NaN
# 84539       Appropriate in length                        Easy
# 85961       Appropriate in length                   Difficult
#
# [5238 rows x 84 columns]

# %%
filt_sex_profession = df_survey_sex["MainBranch"] == "I am a developer by profession"
df_survey_SexPro = df_survey_sex.loc[filt_sex_profession]
df_survey_SexPro
# Out:
#                                 MainBranch Hobbyist  ...  \
# Respondent                                           ...
# 9           I am a developer by profession      Yes  ...
# 26          I am a developer by profession      Yes  ...
# 39          I am a developer by profession      Yes  ...
# 60          I am a developer by profession      Yes  ...
# 100         I am a developer by profession      Yes  ...
# ...                                    ...      ...  ...
# 88800       I am a developer by profession      Yes  ...
# 88845       I am a developer by profession      Yes  ...
# 88865       I am a developer by profession       No  ...
# 88868       I am a developer by profession      Yes  ...
# 88873       I am a developer by profession      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 9           Appropriate in length  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 39          Appropriate in length                        Easy
# 60                            NaN                         NaN
# 100         Appropriate in length                        Easy
# ...                           ...                         ...
# 88800                    Too long  Neither easy nor difficult
# 88845       Appropriate in length                        Easy
# 88865       Appropriate in length                        Easy
# 88868       Appropriate in length                        Easy
# 88873       Appropriate in length                        Easy
#
# [3621 rows x 84 columns]

# %% [markdown]
#     Yukarıdaki tablonun en altında 3.621 rows yazıyor. Yani bizim istediğimiz şartlara uyan 3.621 kişi varmış. Buna shape metodu ile de ulaşılabilir. Aynı şekilde ana tablomuz olan df_survey'e de ulaşılabilir.
#
#     aşağıda sizin için istediğimiz şartları sağlayan kişilerin, toplamda ankete katılan kişilerin yüzde kaçı olduğunu hesaplayacağım:

# %%
rows_sex = df_survey_sex.shape[0]
rows_filter = df_survey_SexPro.shape[0]
rows_nofilter = df_survey.shape[0]

percante = round((rows_filter / rows_nofilter), 2)

print(f"Ankete katılan {rows_sex} kişi ya 'Bisexual' ya da 'Gay or Lesbian' cinsiyetlerine sahipler. Ve bunların da {rows_filter} tanesi, 'I am a develooper by profession' demiştir.")

print(f"Ankete katılan toplam insan sayısı, {rows_nofilter} olduğunda göre: ")

print(f"Ankete katılanların yüzde {percante}'u bizim filtrelerimize uygundur.")
# Out:
# Ankete katılan 5238 kişi ya 'Bisexual' ya da 'Gay or Lesbian' cinsiyetlerine sahipler. Ve bunların da 3621 tanesi, 'I am a develooper by profession' demiştir.
# Ankete katılan toplam insan sayısı, 88883 olduğunda göre:
# Ankete katılanların yüzde 0.04'u bizim filtrelerimize uygundur.

# %% [markdown]
#     Şimdi de başka bir alıştırma yapalım. Biraz inceleyelim öncelikle.

# %%
df_schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
df_schema.loc['YearsCode']['QuestionText']
# Out:
# 'Including any education, how many years have you been coding?'

# %% [markdown]
#     YearsCode'a 5'den fazla cevap verenlerin kaç tanesinde Bechalor's Degree veya Master's Degre yoktur?

# %%
df_survey['YearsCode'].value_counts()
# Out:
# YearsCode
# 5     7047
# 10    6777
# 6     6179
# 4     5729
# 8     5361
#       ...
# 50      51
# 47      36
# 48      31
# 46      27
# 49      25
# Name: count, Length: 52, dtype: int64

# %%
df_survey['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              39134
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           19569
# Some college/university study without earning a degree                                10502
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8642
# Associate degree                                                                       2938
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2432
# Primary/elementary school                                                              1422
# Professional degree (JD, MD, etc.)                                                     1198
# I never completed any formal education                                                  553
# Name: count, dtype: int64

# %%
filt_years = (df_survey['YearsCode'] > "5") & (df_survey['YearsCode'] != "Less than 1 year")    # Less than 1 year bizim düzenimizi bozan bir yanıt olduğu için çıkartıyoruz onur
filt_education = (df_survey['EdLevel'] == "Bachelor’s degree (BA, BS, B.Eng., etc.)") | (df_survey['EdLevel'] == "Master’s degree (MA, MS, M.Eng., MBA, etc.)")

df_years = df_survey.loc[filt_years]

df_final = df_years.loc[~filt_education]        # ÇOK ÖNEMLİ. YUKARIDAKİ filt_education HARİCİNDEKİLERİ SEÇTİK BURADA

ads = df_final[['EdLevel', 'YearsCode']]

ads     # istediğimiz sonucu veren tablo budur
# Out:
#                                                       EdLevel  \
# Respondent
# 27          Some college/university study without earning ...
# 37                                           Associate degree
# 42          Secondary school (e.g. American high school, G...
# 86          Some college/university study without earning ...
# 88          Secondary school (e.g. American high school, G...
# ...                                                       ...
# 72492       Some college/university study without earning ...
# 82789       Secondary school (e.g. American high school, G...
# 83000       Secondary school (e.g. American high school, G...
# 86566       Some college/university study without earning ...
# 88863                      Professional degree (JD, MD, etc.)
#
#                      YearsCode
# Respondent
# 27                           7
# 37                           7
# 42                           8
# 86                           6
# 88                           9
# ...                        ...
# 72492                        7
# 82789                        9
# 83000                        7
# 86566       More than 50 years
# 88863                        8
#
# [6150 rows x 2 columns]

# %% [markdown]
# #### **▶ c) Farklı Filtre Oluşturma Yöntemleri**

# %%
df_survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df_survey['Gender'].value_counts()
# Out:
# Gender
# Man                                                            77919
# Woman                                                           6344
# Non-binary, genderqueer, or gender non-conforming                597
# Man;Non-binary, genderqueer, or gender non-conforming            181
# Woman;Non-binary, genderqueer, or gender non-conforming          163
# Woman;Man                                                        132
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       70
# Name: count, dtype: int64

# %%
genders = ['Man', 'Woman']
filt = df_survey['Gender'].isin(genders)

# %%
df_survey.loc[filt, ['Country', 'Gender']]      # aşağıda sadece Man ve Woman olan bireylerin ülkeleri yer almaktadır.
# Out:
#                            Country Gender
# Respondent
# 1                   United Kingdom    Man
# 2           Bosnia and Herzegovina    Man
# 3                         Thailand    Man
# 4                    United States    Man
# 5                          Ukraine    Man
# ...                            ...    ...
# 88182                     Pakistan    Man
# 88212                        Spain    Man
# 88282                United States    Man
# 88377                       Canada    Man
# 88863                        Spain    Man
#
# [84263 rows x 2 columns]

# %%
countries = ['Turkey']
filt = df_survey['Country'].isin(countries)
df_survey.loc[filt]['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              521
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           117
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    109
# Some college/university study without earning a degree                                 83
# Associate degree                                                                       47
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              23
# Primary/elementary school                                                              16
# I never completed any formal education                                                 12
# Name: count, dtype: int64

# %%
df_survey['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
#     ALIŞTIRMA: Ülkelerin Bachelor's Degree alan yazılımcıların tüm yazılımıclarına oranı kaçtır? Ve aynı şekilde Master's Degree için de geçerli.

# %%
countries = list(set(df_survey['Country']))
countries.pop(0)
countries.sort()

for country in range(0, len(countries)):
    empty_list = []
    empty_list.append(country)
    filt = df_survey['Country'].isin(empty_list)
    filt_All = df_survey.loc[filt]['EdLevel'].shape
    filt_ = df_survey.loc[filt]['EdLevel'].value_counts()
    filt_Bachelor = filt_.loc['Bachelor’s degree (BA, BS, B.Eng., etc.)']
    filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)
    filt_Bachelor_percant = f"{filt_Bachelor_percant}%"
    print(f"Country              : {country[0]}")
    print(f"Number of Participant: {filt_All[0]}")
    print(f"Number of Bacheler's : {filt_Bachelor}")
    print(f"Percant of Bacheler's: {filt_Bachelor_percant}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bachelor’s degree (BA, BS, B.Eng., etc.)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[162], line 11
#       9 filt_All = df_survey.loc[filt]['EdLevel'].shape
#      10 filt_ = df_survey.loc[filt]['EdLevel'].value_counts()
# ---> 11 filt_Bachelor = filt_.loc['Bachelor’s degree (BA, BS, B.Eng., etc.)']
#      12 filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)
#      13 filt_Bachelor_percant = f"{filt_Bachelor_percant}%"
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Bachelor’s degree (BA, BS, B.Eng., etc.)'

# %%
country = ['Turkey', "India"]
filt = df_survey['Country'].isin(country)
filt_All = df_survey.loc[filt]['EdLevel'].shape
filt_ = df_survey.loc[filt]['EdLevel'].value_counts()
filt_Bachelor = filt_.loc['Bachelor’s degree (BA, BS, B.Eng., etc.)']
filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)
filt_Bachelor_percant = f"{filt_Bachelor_percant}%"
print(f"Country              : {country[0]}")
print(f"Number of Participant: {filt_All[0]}")
print(f"Number of Bacheler's : {filt_Bachelor}")
print(f"Percant of Bacheler's: {filt_Bachelor_percant}")
# Out:
# Country              : Turkey
# Number of Participant: 10010
# Number of Bacheler's : 6085
# Percant of Bacheler's: 60%
# C:\Users\monstr\AppData\Local\Temp\ipykernel_9908\2166731113.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)

# %%
countries = list(set(df_survey['Country']))
countries.pop(0)
countries.sort()

for country in range(0, len(countries)):
    empty_list = []
    empty_list.append(country)
    filt = df_survey['Country'].isin(empty_list)
    filt_All = df_survey.loc[filt]['EdLevel'].shape
    filt_ = df_survey.loc[filt]['EdLevel'].value_counts()
    filt_Bachelor = filt_.loc['Bachelor’s degree (BA, BS, B.Eng., etc.)']
    filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)
    filt_Bachelor_percant = f"{filt_Bachelor_percant}%"
    print(f"Country              : {country[0]}")
    print(f"Number of Participant: {filt_All[0]}")
    print(f"Number of Bacheler's : {filt_Bachelor}")
    print(f"Percant of Bacheler's: {filt_Bachelor_percant}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bachelor’s degree (BA, BS, B.Eng., etc.)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[164], line 11
#       9 filt_All = df_survey.loc[filt]['EdLevel'].shape
#      10 filt_ = df_survey.loc[filt]['EdLevel'].value_counts()
# ---> 11 filt_Bachelor = filt_.loc['Bachelor’s degree (BA, BS, B.Eng., etc.)']
#      12 filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)
#      13 filt_Bachelor_percant = f"{filt_Bachelor_percant}%"
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Bachelor’s degree (BA, BS, B.Eng., etc.)'

# %%
country = ['Turkey', "India"]
for i in range(2):
    empty_list = []
    empty_list.append(country)
    filt = df_survey['Country'].isin(empty_list)
    filt_All = df_survey.loc[filt]['EdLevel'].shape
    filt_ = df_survey.loc[filt]['EdLevel'].value_counts()
    filt_Bachelor = filt_.loc['Bachelor’s degree (BA, BS, B.Eng., etc.)']
    filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)
    filt_Bachelor_percant = f"{filt_Bachelor_percant}%"
    print(f"Country              : {country[0]}")
    print(f"Number of Participant: {filt_All[0]}")
    print(f"Number of Bacheler's : {filt_Bachelor}")
    print(f"Percant of Bacheler's: {filt_Bachelor_percant}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bachelor’s degree (BA, BS, B.Eng., etc.)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[165], line 8
#       6 filt_All = df_survey.loc[filt]['EdLevel'].shape
#       7 filt_ = df_survey.loc[filt]['EdLevel'].value_counts()
# ----> 8 filt_Bachelor = filt_.loc['Bachelor’s degree (BA, BS, B.Eng., etc.)']
#       9 filt_Bachelor_percant = int((filt_Bachelor / filt_All) * 100)
#      10 filt_Bachelor_percant = f"{filt_Bachelor_percant}%"
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Bachelor’s degree (BA, BS, B.Eng., etc.)'

# %% [markdown]
#     ALIŞTIRMA: Ülkelerin Bachelor's Degree alan yazılımcıların tüm yazılımıclarına oranı kaçtır? Ve aynı şekilde Master's Degree için de geçerli.

# %%
a = df_survey['Country'].value_counts()
a       # burada tüm ülkeleri listeledik unique bir biçimde.

my_dict = dict(a)
my_dict     # burada ise bir dictionary'e çevirdik.

my_list = my_dict.keys()
my_list = list(my_list)
my_list    # burada ülkeleri liste haline getirdik iterable olması için.

for ülke in my_list:

    ülke = [ülke]        # filtrelemek istediğimiz şehri bir liste içerisine yazarız

    filt = df_survey['Country'].isin(ülke)   # yalnızca Turkey olan row'lar True hale getirildi.

    df_survey.loc[filt]         # herhangi bir column belirtmediğimiz için tüm Turkey olan row'lar yazdırıldı.

    df_survey.loc[filt]['EdLevel']      # bu şekilde türklerin eğitim durumlarının ne olduğu tablo haline getirildi

    list_EdLevel = df_survey.loc[filt]['EdLevel'].value_counts()       # bu şekilde de tüm yanıtlar unique hale getirildi

    text = "Bachelor’s degree (BA, BS, B.Eng., etc.)"

    if text in list_EdLevel:
        bachelor_sayısı = list_EdLevel.loc["Bachelor’s degree (BA, BS, B.Eng., etc.)"]

        tüm_sayı = df_survey.loc[filt]['EdLevel'].shape
        tüm_sayı = tüm_sayı[0]

        oran = round((bachelor_sayısı / tüm_sayı) * 100)


        print("🟢 Ülke Adı:", ülke[0])
        print("▶ Katılımcı Sayısı:", tüm_sayı)
        print("▶ Lisans Mezunu:", bachelor_sayısı)
        print("▶ Mezun Oranı: " + str(oran) + "%" + "\n")
# Out:
# 🟢 Ülke Adı: United States
# ▶ Katılımcı Sayısı: 20949
# ▶ Lisans Mezunu: 10953
# ▶ Mezun Oranı: 52%
#
# 🟢 Ülke Adı: India
# ▶ Katılımcı Sayısı: 9061
# ▶ Lisans Mezunu: 5564
# ▶ Mezun Oranı: 61%
#
# 🟢 Ülke Adı: Germany
# ▶ Katılımcı Sayısı: 5866
# ▶ Lisans Mezunu: 1555
# ▶ Mezun Oranı: 27%
#
# 🟢 Ülke Adı: United Kingdom
# ▶ Katılımcı Sayısı: 5737
# ▶ Lisans Mezunu: 2547
# ▶ Mezun Oranı: 44%
#
# 🟢 Ülke Adı: Canada
# ▶ Katılımcı Sayısı: 3395
# ▶ Lisans Mezunu: 1588
# ▶ Mezun Oranı: 47%
#
# 🟢 Ülke Adı: France
# ▶ Katılımcı Sayısı: 2391
# ▶ Lisans Mezunu: 395
# ▶ Mezun Oranı: 17%
#
# 🟢 Ülke Adı: Brazil
# ▶ Katılımcı Sayısı: 1948
# ▶ Lisans Mezunu: 908
# ▶ Mezun Oranı: 47%
#
# 🟢 Ülke Adı: Poland
# ▶ Katılımcı Sayısı: 1922
# ▶ Lisans Mezunu: 557
# ▶ Mezun Oranı: 29%
#
# 🟢 Ülke Adı: Australia
# ▶ Katılımcı Sayısı: 1903
# ▶ Lisans Mezunu: 1006
# ▶ Mezun Oranı: 53%
#
# 🟢 Ülke Adı: Netherlands
# ▶ Katılımcı Sayısı: 1852
# ▶ Lisans Mezunu: 724
# ▶ Mezun Oranı: 39%
#
# 🟢 Ülke Adı: Russian Federation
# ▶ Katılımcı Sayısı: 1694
# ▶ Lisans Mezunu: 439
# ▶ Mezun Oranı: 26%
#
# 🟢 Ülke Adı: Spain
# ▶ Katılımcı Sayısı: 1604
# ▶ Lisans Mezunu: 505
# ▶ Mezun Oranı: 31%
#
# 🟢 Ülke Adı: Italy
# ▶ Katılımcı Sayısı: 1576
# ▶ Lisans Mezunu: 371
# ▶ Mezun Oranı: 24%
#
# 🟢 Ülke Adı: Sweden
# ▶ Katılımcı Sayısı: 1274
# ▶ Lisans Mezunu: 330
# ▶ Mezun Oranı: 26%
#
# 🟢 Ülke Adı: Switzerland
# ▶ Katılımcı Sayısı: 978
# ▶ Lisans Mezunu: 253
# ▶ Mezun Oranı: 26%
#
# 🟢 Ülke Adı: Israel
# ▶ Katılımcı Sayısı: 952
# ▶ Lisans Mezunu: 447
# ▶ Mezun Oranı: 47%
#
# 🟢 Ülke Adı: Turkey
# ▶ Katılımcı Sayısı: 949
# ▶ Lisans Mezunu: 521
# ▶ Mezun Oranı: 55%
#
# 🟢 Ülke Adı: Pakistan
# ▶ Katılımcı Sayısı: 923
# ▶ Lisans Mezunu: 584
# ▶ Mezun Oranı: 63%
#
# 🟢 Ülke Adı: Ukraine
# ▶ Katılımcı Sayısı: 868
# ▶ Lisans Mezunu: 224
# ▶ Mezun Oranı: 26%
#
# 🟢 Ülke Adı: Austria
# ▶ Katılımcı Sayısı: 839
# ▶ Lisans Mezunu: 173
# ▶ Mezun Oranı: 21%
#
# 🟢 Ülke Adı: Czech Republic
# ▶ Katılımcı Sayısı: 764
# ▶ Lisans Mezunu: 151
# ▶ Mezun Oranı: 20%
#
# 🟢 Ülke Adı: Romania
# ▶ Katılımcı Sayısı: 760
# ▶ Lisans Mezunu: 350
# ▶ Mezun Oranı: 46%
#
# 🟢 Ülke Adı: Iran
# ▶ Katılımcı Sayısı: 738
# ▶ Lisans Mezunu: 345
# ▶ Mezun Oranı: 47%
#
# 🟢 Ülke Adı: Belgium
# ▶ Katılımcı Sayısı: 727
# ▶ Lisans Mezunu: 285
# ▶ Mezun Oranı: 39%
#
# 🟢 Ülke Adı: China
# ▶ Katılımcı Sayısı: 664
# ▶ Lisans Mezunu: 341
# ▶ Mezun Oranı: 51%
#
# 🟢 Ülke Adı: Bulgaria
# ▶ Katılımcı Sayısı: 659
# ▶ Lisans Mezunu: 238
# ▶ Mezun Oranı: 36%
#
# 🟢 Ülke Adı: Mexico
# ▶ Katılımcı Sayısı: 642
# ▶ Lisans Mezunu: 334
# ▶ Mezun Oranı: 52%
#
# 🟢 Ülke Adı: South Africa
# ▶ Katılımcı Sayısı: 627
# ▶ Lisans Mezunu: 259
# ▶ Mezun Oranı: 41%
#
# 🟢 Ülke Adı: Denmark
# ▶ Katılımcı Sayısı: 617
# ▶ Lisans Mezunu: 173
# ▶ Mezun Oranı: 28%
#
# 🟢 Ülke Adı: Bangladesh
# ▶ Katılımcı Sayısı: 605
# ▶ Lisans Mezunu: 377
# ▶ Mezun Oranı: 62%
#
# 🟢 Ülke Adı: Norway
# ▶ Katılımcı Sayısı: 574
# ▶ Lisans Mezunu: 203
# ▶ Mezun Oranı: 35%
#
# 🟢 Ülke Adı: Greece
# ▶ Katılımcı Sayısı: 556
# ▶ Lisans Mezunu: 177
# ▶ Mezun Oranı: 32%
#
# 🟢 Ülke Adı: Argentina
# ▶ Katılımcı Sayısı: 553
# ▶ Lisans Mezunu: 128
# ▶ Mezun Oranı: 23%
#
# 🟢 Ülke Adı: Finland
# ▶ Katılımcı Sayısı: 546
# ▶ Lisans Mezunu: 171
# ▶ Mezun Oranı: 31%
#
# 🟢 Ülke Adı: Portugal
# ▶ Katılımcı Sayısı: 525
# ▶ Lisans Mezunu: 163
# ▶ Mezun Oranı: 31%
#
# 🟢 Ülke Adı: New Zealand
# ▶ Katılımcı Sayısı: 524
# ▶ Lisans Mezunu: 286
# ▶ Mezun Oranı: 55%
#
# 🟢 Ülke Adı: Nigeria
# ▶ Katılımcı Sayısı: 522
# ▶ Lisans Mezunu: 265
# ▶ Mezun Oranı: 51%
#
# 🟢 Ülke Adı: Hungary
# ▶ Katılımcı Sayısı: 513
# ▶ Lisans Mezunu: 156
# ▶ Mezun Oranı: 30%
#
# 🟢 Ülke Adı: Indonesia
# ▶ Katılımcı Sayısı: 507
# ▶ Lisans Mezunu: 254
# ▶ Mezun Oranı: 50%
#
# 🟢 Ülke Adı: Ireland
# ▶ Katılımcı Sayısı: 501
# ▶ Lisans Mezunu: 235
# ▶ Mezun Oranı: 47%
#
# 🟢 Ülke Adı: Serbia
# ▶ Katılımcı Sayısı: 402
# ▶ Lisans Mezunu: 138
# ▶ Mezun Oranı: 34%
#
# 🟢 Ülke Adı: Japan
# ▶ Katılımcı Sayısı: 391
# ▶ Lisans Mezunu: 178
# ▶ Mezun Oranı: 46%
#
# 🟢 Ülke Adı: Philippines
# ▶ Katılımcı Sayısı: 381
# ▶ Lisans Mezunu: 282
# ▶ Mezun Oranı: 74%
#
# 🟢 Ülke Adı: Sri Lanka
# ▶ Katılımcı Sayısı: 372
# ▶ Lisans Mezunu: 220
# ▶ Mezun Oranı: 59%
#
# 🟢 Ülke Adı: Egypt
# ▶ Katılımcı Sayısı: 323
# ▶ Lisans Mezunu: 207
# ▶ Mezun Oranı: 64%
#
# 🟢 Ülke Adı: Colombia
# ▶ Katılımcı Sayısı: 313
# ▶ Lisans Mezunu: 116
# ▶ Mezun Oranı: 37%
#
# 🟢 Ülke Adı: Singapore
# ▶ Katılımcı Sayısı: 303
# ▶ Lisans Mezunu: 153
# ▶ Mezun Oranı: 50%
#
# 🟢 Ülke Adı: Malaysia
# ▶ Katılımcı Sayısı: 299
# ▶ Lisans Mezunu: 181
# ▶ Mezun Oranı: 61%
#
# 🟢 Ülke Adı: Slovenia
# ▶ Katılımcı Sayısı: 298
# ▶ Lisans Mezunu: 126
# ▶ Mezun Oranı: 42%
#
# 🟢 Ülke Adı: Slovakia
# ▶ Katılımcı Sayısı: 260
# ▶ Lisans Mezunu: 36
# ▶ Mezun Oranı: 14%
#
# 🟢 Ülke Adı: Croatia
# ▶ Katılımcı Sayısı: 260
# ▶ Lisans Mezunu: 71
# ▶ Mezun Oranı: 27%
#
# 🟢 Ülke Adı: Kenya
# ▶ Katılımcı Sayısı: 249
# ▶ Lisans Mezunu: 143
# ▶ Mezun Oranı: 57%
#
# 🟢 Ülke Adı: Lithuania
# ▶ Katılımcı Sayısı: 248
# ▶ Lisans Mezunu: 105
# ▶ Mezun Oranı: 42%
#
# 🟢 Ülke Adı: Nepal
# ▶ Katılımcı Sayısı: 237
# ▶ Lisans Mezunu: 167
# ▶ Mezun Oranı: 70%
#
# 🟢 Ülke Adı: Viet Nam
# ▶ Katılımcı Sayısı: 231
# ▶ Lisans Mezunu: 98
# ▶ Mezun Oranı: 42%
#
# 🟢 Ülke Adı: Thailand
# ▶ Katılımcı Sayısı: 214
# ▶ Lisans Mezunu: 104
# ▶ Mezun Oranı: 49%
#
# 🟢 Ülke Adı: Chile
# ▶ Katılımcı Sayısı: 206
# ▶ Lisans Mezunu: 77
# ▶ Mezun Oranı: 37%
#
# 🟢 Ülke Adı: Belarus
# ▶ Katılımcı Sayısı: 202
# ▶ Lisans Mezunu: 85
# ▶ Mezun Oranı: 42%
#
# 🟢 Ülke Adı: Estonia
# ▶ Katılımcı Sayısı: 195
# ▶ Lisans Mezunu: 58
# ▶ Mezun Oranı: 30%
#
# 🟢 Ülke Adı: Hong Kong (S.A.R.)
# ▶ Katılımcı Sayısı: 188
# ▶ Lisans Mezunu: 101
# ▶ Mezun Oranı: 54%
#
# 🟢 Ülke Adı: Taiwan
# ▶ Katılımcı Sayısı: 187
# ▶ Lisans Mezunu: 70
# ▶ Mezun Oranı: 37%
#
# 🟢 Ülke Adı: South Korea
# ▶ Katılımcı Sayısı: 160
# ▶ Lisans Mezunu: 76
# ▶ Mezun Oranı: 48%
#
# 🟢 Ülke Adı: United Arab Emirates
# ▶ Katılımcı Sayısı: 158
# ▶ Lisans Mezunu: 93
# ▶ Mezun Oranı: 59%
#
# 🟢 Ülke Adı: Morocco
# ▶ Katılımcı Sayısı: 155
# ▶ Lisans Mezunu: 49
# ▶ Mezun Oranı: 32%
#
# 🟢 Ülke Adı: Other Country (Not Listed Above)
# ▶ Katılımcı Sayısı: 136
# ▶ Lisans Mezunu: 53
# ▶ Mezun Oranı: 39%
#
# 🟢 Ülke Adı: Latvia
# ▶ Katılımcı Sayısı: 136
# ▶ Lisans Mezunu: 46
# ▶ Mezun Oranı: 34%
#
# 🟢 Ülke Adı: Algeria
# ▶ Katılımcı Sayısı: 134
# ▶ Lisans Mezunu: 31
# ▶ Mezun Oranı: 23%
#
# 🟢 Ülke Adı: Tunisia
# ▶ Katılımcı Sayısı: 130
# ▶ Lisans Mezunu: 34
# ▶ Mezun Oranı: 26%
#
# 🟢 Ülke Adı: Peru
# ▶ Katılımcı Sayısı: 130
# ▶ Lisans Mezunu: 62
# ▶ Mezun Oranı: 48%
#
# 🟢 Ülke Adı: Lebanon
# ▶ Katılımcı Sayısı: 120
# ▶ Lisans Mezunu: 67
# ▶ Mezun Oranı: 56%
#
# 🟢 Ülke Adı: Uruguay
# ▶ Katılımcı Sayısı: 111
# ▶ Lisans Mezunu: 48
# ▶ Mezun Oranı: 43%
#
# 🟢 Ülke Adı: Bosnia and Herzegovina
# ▶ Katılımcı Sayısı: 108
# ▶ Lisans Mezunu: 31
# ▶ Mezun Oranı: 29%
#
# 🟢 Ülke Adı: Saudi Arabia
# ▶ Katılımcı Sayısı: 98
# ▶ Lisans Mezunu: 52
# ▶ Mezun Oranı: 53%
#
# 🟢 Ülke Adı: Dominican Republic
# ▶ Katılımcı Sayısı: 97
# ▶ Lisans Mezunu: 41
# ▶ Mezun Oranı: 42%
#
# 🟢 Ülke Adı: Venezuela, Bolivarian Republic of...
# ▶ Katılımcı Sayısı: 88
# ▶ Lisans Mezunu: 28
# ▶ Mezun Oranı: 32%
#
# 🟢 Ülke Adı: Albania
# ▶ Katılımcı Sayısı: 86
# ▶ Lisans Mezunu: 37
# ▶ Mezun Oranı: 43%
#
# 🟢 Ülke Adı: Armenia
# ▶ Katılımcı Sayısı: 86
# ▶ Lisans Mezunu: 36
# ▶ Mezun Oranı: 42%
#
# 🟢 Ülke Adı: Costa Rica
# ▶ Katılımcı Sayısı: 84
# ▶ Lisans Mezunu: 47
# ▶ Mezun Oranı: 56%
#
# 🟢 Ülke Adı: Ghana
# ▶ Katılımcı Sayısı: 84
# ▶ Lisans Mezunu: 51
# ▶ Mezun Oranı: 61%
#
# 🟢 Ülke Adı: Ecuador
# ▶ Katılımcı Sayısı: 82
# ▶ Lisans Mezunu: 42
# ▶ Mezun Oranı: 51%
#
# 🟢 Ülke Adı: Georgia
# ▶ Katılımcı Sayısı: 80
# ▶ Lisans Mezunu: 42
# ▶ Mezun Oranı: 52%
#
# 🟢 Ülke Adı: Uganda
# ▶ Katılımcı Sayısı: 72
# ▶ Lisans Mezunu: 48
# ▶ Mezun Oranı: 67%
#
# 🟢 Ülke Adı: Guatemala
# ▶ Katılımcı Sayısı: 67
# ▶ Lisans Mezunu: 27
# ▶ Mezun Oranı: 40%
#
# 🟢 Ülke Adı: El Salvador
# ▶ Katılımcı Sayısı: 67
# ▶ Lisans Mezunu: 27
# ▶ Mezun Oranı: 40%
#
# 🟢 Ülke Adı: Malta
# ▶ Katılımcı Sayısı: 65
# ▶ Lisans Mezunu: 34
# ▶ Mezun Oranı: 52%
#
# 🟢 Ülke Adı: Jordan
# ▶ Katılımcı Sayısı: 65
# ▶ Lisans Mezunu: 45
# ▶ Mezun Oranı: 69%
#
# 🟢 Ülke Adı: Kazakhstan
# ▶ Katılımcı Sayısı: 64
# ▶ Lisans Mezunu: 28
# ▶ Mezun Oranı: 44%
#
# 🟢 Ülke Adı: Cyprus
# ▶ Katılımcı Sayısı: 64
# ▶ Lisans Mezunu: 23
# ▶ Mezun Oranı: 36%
#
# 🟢 Ülke Adı: Luxembourg
# ▶ Katılımcı Sayısı: 61
# ▶ Lisans Mezunu: 17
# ▶ Mezun Oranı: 28%
#
# 🟢 Ülke Adı: The former Yugoslav Republic of Macedonia
# ▶ Katılımcı Sayısı: 54
# ▶ Lisans Mezunu: 34
# ▶ Mezun Oranı: 63%
#
# 🟢 Ülke Adı: Paraguay
# ▶ Katılımcı Sayısı: 52
# ▶ Lisans Mezunu: 22
# ▶ Mezun Oranı: 42%
#
# 🟢 Ülke Adı: Ethiopia
# ▶ Katılımcı Sayısı: 52
# ▶ Lisans Mezunu: 28
# ▶ Mezun Oranı: 54%
#
# 🟢 Ülke Adı: Myanmar
# ▶ Katılımcı Sayısı: 52
# ▶ Lisans Mezunu: 28
# ▶ Mezun Oranı: 54%
#
# 🟢 Ülke Adı: Cameroon
# ▶ Katılımcı Sayısı: 51
# ▶ Lisans Mezunu: 23
# ▶ Mezun Oranı: 45%
#
# 🟢 Ülke Adı: Azerbaijan
# ▶ Katılımcı Sayısı: 49
# ▶ Lisans Mezunu: 25
# ▶ Mezun Oranı: 51%
#
# 🟢 Ülke Adı: Iceland
# ▶ Katılımcı Sayısı: 49
# ▶ Lisans Mezunu: 21
# ▶ Mezun Oranı: 43%
#
# 🟢 Ülke Adı: Afghanistan
# ▶ Katılımcı Sayısı: 44
# ▶ Lisans Mezunu: 17
# ▶ Mezun Oranı: 39%
#
# 🟢 Ülke Adı: Republic of Moldova
# ▶ Katılımcı Sayısı: 43
# ▶ Lisans Mezunu: 20
# ▶ Mezun Oranı: 47%
#
# 🟢 Ülke Adı: Sudan
# ▶ Katılımcı Sayısı: 42
# ▶ Lisans Mezunu: 25
# ▶ Mezun Oranı: 60%
#
# 🟢 Ülke Adı: Iraq
# ▶ Katılımcı Sayısı: 39
# ▶ Lisans Mezunu: 20
# ▶ Mezun Oranı: 51%
#
# 🟢 Ülke Adı: Zimbabwe
# ▶ Katılımcı Sayısı: 39
# ▶ Lisans Mezunu: 19
# ▶ Mezun Oranı: 49%
#
# 🟢 Ülke Adı: Uzbekistan
# ▶ Katılımcı Sayısı: 39
# ▶ Lisans Mezunu: 23
# ▶ Mezun Oranı: 59%
#
# 🟢 Ülke Adı: Republic of Korea
# ▶ Katılımcı Sayısı: 39
# ▶ Lisans Mezunu: 16
# ▶ Mezun Oranı: 41%
#
# 🟢 Ülke Adı: Bolivia
# ▶ Katılımcı Sayısı: 36
# ▶ Lisans Mezunu: 17
# ▶ Mezun Oranı: 47%
#
# 🟢 Ülke Adı: Côte d'Ivoire
# ▶ Katılımcı Sayısı: 34
# ▶ Lisans Mezunu: 12
# ▶ Mezun Oranı: 35%
#
# 🟢 Ülke Adı: Panama
# ▶ Katılımcı Sayısı: 33
# ▶ Lisans Mezunu: 15
# ▶ Mezun Oranı: 45%
#
# 🟢 Ülke Adı: United Republic of Tanzania
# ▶ Katılımcı Sayısı: 32
# ▶ Lisans Mezunu: 19
# ▶ Mezun Oranı: 59%
#
# 🟢 Ülke Adı: Cambodia
# ▶ Katılımcı Sayısı: 30
# ▶ Lisans Mezunu: 13
# ▶ Mezun Oranı: 43%
#
# 🟢 Ülke Adı: Cuba
# ▶ Katılımcı Sayısı: 30
# ▶ Lisans Mezunu: 19
# ▶ Mezun Oranı: 63%
#
# 🟢 Ülke Adı: Nicaragua
# ▶ Katılımcı Sayısı: 30
# ▶ Lisans Mezunu: 11
# ▶ Mezun Oranı: 37%
#
# 🟢 Ülke Adı: Syrian Arab Republic
# ▶ Katılımcı Sayısı: 29
# ▶ Lisans Mezunu: 13
# ▶ Mezun Oranı: 45%
#
# 🟢 Ülke Adı: Jamaica
# ▶ Katılımcı Sayısı: 28
# ▶ Lisans Mezunu: 12
# ▶ Mezun Oranı: 43%
#
# 🟢 Ülke Adı: Honduras
# ▶ Katılımcı Sayısı: 27
# ▶ Lisans Mezunu: 13
# ▶ Mezun Oranı: 48%
#
# 🟢 Ülke Adı: Mauritius
# ▶ Katılımcı Sayısı: 26
# ▶ Lisans Mezunu: 17
# ▶ Mezun Oranı: 65%
#
# 🟢 Ülke Adı: Senegal
# ▶ Katılımcı Sayısı: 21
# ▶ Lisans Mezunu: 5
# ▶ Mezun Oranı: 24%
#
# 🟢 Ülke Adı: Kuwait
# ▶ Katılımcı Sayısı: 20
# ▶ Lisans Mezunu: 11
# ▶ Mezun Oranı: 55%
#
# 🟢 Ülke Adı: Yemen
# ▶ Katılımcı Sayısı: 19
# ▶ Lisans Mezunu: 15
# ▶ Mezun Oranı: 79%
#
# 🟢 Ülke Adı: Trinidad and Tobago
# ▶ Katılımcı Sayısı: 19
# ▶ Lisans Mezunu: 7
# ▶ Mezun Oranı: 37%
#
# 🟢 Ülke Adı: Kyrgyzstan
# ▶ Katılımcı Sayısı: 19
# ▶ Lisans Mezunu: 7
# ▶ Mezun Oranı: 37%
#
# 🟢 Ülke Adı: Bahrain
# ▶ Katılımcı Sayısı: 18
# ▶ Lisans Mezunu: 11
# ▶ Mezun Oranı: 61%
#
# 🟢 Ülke Adı: Mongolia
# ▶ Katılımcı Sayısı: 17
# ▶ Lisans Mezunu: 10
# ▶ Mezun Oranı: 59%
#
# 🟢 Ülke Adı: Montenegro
# ▶ Katılımcı Sayısı: 17
# ▶ Lisans Mezunu: 7
# ▶ Mezun Oranı: 41%
#
# 🟢 Ülke Adı: Madagascar
# ▶ Katılımcı Sayısı: 15
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 13%
#
# 🟢 Ülke Adı: Somalia
# ▶ Katılımcı Sayısı: 13
# ▶ Lisans Mezunu: 8
# ▶ Mezun Oranı: 62%
#
# 🟢 Ülke Adı: Qatar
# ▶ Katılımcı Sayısı: 13
# ▶ Lisans Mezunu: 9
# ▶ Mezun Oranı: 69%
#
# 🟢 Ülke Adı: Maldives
# ▶ Katılımcı Sayısı: 13
# ▶ Lisans Mezunu: 4
# ▶ Mezun Oranı: 31%
#
# 🟢 Ülke Adı: Zambia
# ▶ Katılımcı Sayısı: 12
# ▶ Lisans Mezunu: 7
# ▶ Mezun Oranı: 58%
#
# 🟢 Ülke Adı: Rwanda
# ▶ Katılımcı Sayısı: 12
# ▶ Lisans Mezunu: 10
# ▶ Mezun Oranı: 83%
#
# 🟢 Ülke Adı: Oman
# ▶ Katılımcı Sayısı: 11
# ▶ Lisans Mezunu: 3
# ▶ Mezun Oranı: 27%
#
# 🟢 Ülke Adı: Libyan Arab Jamahiriya
# ▶ Katılımcı Sayısı: 10
# ▶ Lisans Mezunu: 7
# ▶ Mezun Oranı: 70%
#
# 🟢 Ülke Adı: Congo, Republic of the...
# ▶ Katılımcı Sayısı: 7
# ▶ Lisans Mezunu: 5
# ▶ Mezun Oranı: 71%
#
# 🟢 Ülke Adı: Turkmenistan
# ▶ Katılımcı Sayısı: 7
# ▶ Lisans Mezunu: 3
# ▶ Mezun Oranı: 43%
#
# 🟢 Ülke Adı: Democratic Republic of the Congo
# ▶ Katılımcı Sayısı: 7
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 14%
#
# 🟢 Ülke Adı: Tajikistan
# ▶ Katılımcı Sayısı: 7
# ▶ Lisans Mezunu: 4
# ▶ Mezun Oranı: 57%
#
# 🟢 Ülke Adı: Mauritania
# ▶ Katılımcı Sayısı: 7
# ▶ Lisans Mezunu: 3
# ▶ Mezun Oranı: 43%
#
# 🟢 Ülke Adı: Mozambique
# ▶ Katılımcı Sayısı: 7
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 29%
#
# 🟢 Ülke Adı: Botswana
# ▶ Katılımcı Sayısı: 5
# ▶ Lisans Mezunu: 3
# ▶ Mezun Oranı: 60%
#
# 🟢 Ülke Adı: Benin
# ▶ Katılımcı Sayısı: 5
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 40%
#
# 🟢 Ülke Adı: Angola
# ▶ Katılımcı Sayısı: 5
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 20%
#
# 🟢 Ülke Adı: Namibia
# ▶ Katılımcı Sayısı: 5
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 40%
#
# 🟢 Ülke Adı: Haiti
# ▶ Katılımcı Sayısı: 5
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 40%
#
# 🟢 Ülke Adı: Fiji
# ▶ Katılımcı Sayısı: 5
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 20%
#
# 🟢 Ülke Adı: Burkina Faso
# ▶ Katılımcı Sayısı: 4
# ▶ Lisans Mezunu: 3
# ▶ Mezun Oranı: 75%
#
# 🟢 Ülke Adı: Monaco
# ▶ Katılımcı Sayısı: 4
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 25%
#
# 🟢 Ülke Adı: Togo
# ▶ Katılımcı Sayısı: 4
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 50%
#
# 🟢 Ülke Adı: Mali
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 33%
#
# 🟢 Ülke Adı: Lesotho
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 3
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Barbados
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 33%
#
# 🟢 Ülke Adı: Belize
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 33%
#
# 🟢 Ülke Adı: Cape Verde
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 33%
#
# 🟢 Ülke Adı: Democratic People's Republic of Korea
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 33%
#
# 🟢 Ülke Adı: Guinea
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 33%
#
# 🟢 Ülke Adı: Lao People's Democratic Republic
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 67%
#
# 🟢 Ülke Adı: Burundi
# ▶ Katılımcı Sayısı: 3
# ▶ Lisans Mezunu: 3
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Bhutan
# ▶ Katılımcı Sayısı: 2
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Djibouti
# ▶ Katılımcı Sayısı: 2
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 50%
#
# 🟢 Ülke Adı: Malawi
# ▶ Katılımcı Sayısı: 2
# ▶ Lisans Mezunu: 2
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: San Marino
# ▶ Katılımcı Sayısı: 2
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 50%
#
# 🟢 Ülke Adı: Sierra Leone
# ▶ Katılımcı Sayısı: 2
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 50%
#
# 🟢 Ülke Adı: Sao Tome and Principe
# ▶ Katılımcı Sayısı: 1
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Saint Vincent and the Grenadines
# ▶ Katılımcı Sayısı: 1
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Niger
# ▶ Katılımcı Sayısı: 1
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Papua New Guinea
# ▶ Katılımcı Sayısı: 1
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: North Korea
# ▶ Katılımcı Sayısı: 1
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Brunei Darussalam
# ▶ Katılımcı Sayısı: 1
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 100%
#
# 🟢 Ülke Adı: Chad
# ▶ Katılımcı Sayısı: 1
# ▶ Lisans Mezunu: 1
# ▶ Mezun Oranı: 100%

# %% [markdown]
# ## **▶️▶️ 2.5 Metodlar**

# %% [markdown]
# #### **🗣️ set_index() - 🗣️ reset_index()**

# %% [markdown]
#     Bu metodu kullanarak bir tablo'nun index column'unu değiştirebiliyoruz.
#
#     Örneğin poeple tablosunda index olarak pandas ın standart olarak uyguladığım indexler yer almaktadır. O index column'u yerine pople tablosu içeriisnde yer alan "first" column'unu index column'u olarak tayin edebilirz. Böylelikle iloc yerine loc metodunu kullanarak tabloda daha yüksek bir hakimiyet kurabiliriz.

# %%
# görüldüğü gibi indexler standart pandas indexi:
 
df_people
# Out:
#           first     last                    email  new
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 3         Hacer    Çakır                      yok  NaN
# 4        Halise  Çukurlu                      yok  NaN

# %%
# aşağıdaki kod uygulandıktan sonra artık first column'unu biz index olarak kullanabileceğiz.

df_people.set_index('first', inplace=True)  # inplace=True parametresini kullanmamış olsaydık, dataframe eski halini korurdu. indexleme işlemi sadece bu hücre için geçerli olurdu
df_people
# Out:
#                  last                    email  new
# first
# Emre            ÇAKIR      emrecakir@gmail.com  NaN
# İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# Hacer           Çakır                      yok  NaN
# Halise        Çukurlu                      yok  NaN

# %%
df_people.loc['Emre']

# loc[] kullanarak Emre ismine ait soyisim ve email bilgilerine pratik şekilde ulaşırız
# Out:
# last                   ÇAKIR
# email    emrecakir@gmail.com
# new                      NaN
# Name: Emre, dtype: object

# %%
df_people.reset_index(inplace=True)     # aynı şekilde burada inplace=True kullanmamış olsaydık değişiklik sadece bu hücrede geçerli olmuş olacaktı
df_people
# Out:
#           first     last                    email  new
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 3         Hacer    Çakır                      yok  NaN
# 4        Halise  Çukurlu                      yok  NaN

# %%
df_people2 = df_people.set_index('first')
df_people2      # bu tablo bu şekilde kalsın
# Out:
#                  last                    email  new
# first
# Emre            ÇAKIR      emrecakir@gmail.com  NaN
# İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# Hacer           Çakır                      yok  NaN
# Halise        Çukurlu                      yok  NaN

# %% [markdown]
# #### **🗣️ sort_index() Metodu**

# %% [markdown]
#     Bu metodu kullanarak index column'unu sıralayabiliriz, mesela alfabetik sıraya göre.

# %%
df_schema.sort_index().head(4)
# Out:
#                                                    QuestionText
# Column
# Age           What is your age (in years)? If you prefer not...
# Age1stCode    At what age did you write your first line of c...
# BetterLife    Do you think people born today will have a bet...
# BlockchainIs  Blockchain / cryptocurrency technology is prim...

# %%
df_schema.sort_index(ascending=False)
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
df_schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %% [markdown]
# > **Yukarıda görüldüğü gibi afabetik olarak hem A'dan Z'ye hem de Z'den A'ya doğru sıralamam rağmen orijinl tablo değişmedi. Çünkü Herhangi bir atama işlemi yapmadık.**

# %%
df_schema2 = df_schema.sort_index()
df_schema2      # bundan sonra alfabetik olarak sıralanmış bir schema tablomuz var.
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %% [markdown]
# > **Ya da şöyle yapabiliriz:**

# %%
df_people2.sort_index(ascending=False, inplace=True)
df_people2      # ascending=False kullanarak z'den a'ya doğru sıraladık index column'unu. inpalce=True kullanarak da doğrudan atama yaptık.
# not: İ harfi ingilizcede olmadığı için o harfi birinci sıraya atadı.
# Out:
#                  last                    email  new
# first
# İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# Halise        Çukurlu                      yok  NaN
# Hacer           Çakır                      yok  NaN
# Emre            ÇAKIR      emrecakir@gmail.com  NaN
# Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN

# %% [markdown]
# ##### **🗣️ sort_values() metodu**

# %%
df_people = df_people.sort_values(by = 'email', ascending = False )

df_people
# Out:
#           first     last                    email  new
# 3         Hacer    Çakır                      yok  NaN
# 4        Halise  Çukurlu                      yok  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN

# %%
df_people = df_people.sort_values(by = ['last' , 'first'], ascending = False )

df_people
# Out:
#           first     last                    email  new
# 4        Halise  Çukurlu                      yok  NaN
# 3         Hacer    Çakır                      yok  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN

# %%
df_people.sort_values(by = ['last' , 'first'], ascending = [False, True], inplace = True )
df_people
# Out:
#           first     last                    email  new
# 4        Halise  Çukurlu                      yok  NaN
# 3         Hacer    Çakır                      yok  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN

# %%
df_people['new'].sort_values()
# Out:
# 4    NaN
# 3    NaN
# 2    NaN
# 1    NaN
# 0    NaN
# Name: new, dtype: object

# %% [markdown]
# #### **🗣️ apply() Metodu**

# %%
df_people['email'].apply(len) # len() metodunu tüm 'email' column'una uyguladık ve sonucu yazdırdık
# Out:
# 4     3
# 3     3
# 2    23
# 1    20
# 0    19
# Name: email, dtype: int64

# %%
df_people       # bir önceki işlem ana tabloyu etkilenmez.
# Out:
#           first     last                    email  new
# 4        Halise  Çukurlu                      yok  NaN
# 3         Hacer    Çakır                      yok  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN

# %%
df_people['email']= df_people['email'].apply(len) # bu kodu çalıştırarak ana tabloya etki etmiş olduk
df_people
# Out:
#           first     last  email  new
# 4        Halise  Çukurlu      3  NaN
# 3         Hacer    Çakır      3  NaN
# 2  Ceren İlayda  ÇUKURLU     23  NaN
# 1  İrem Süheyla  ÇUKURLU     20  NaN
# 0          Emre    ÇAKIR     19  NaN

# %%
df_people.loc[0, "email"] =  "emrecakir@gmail.com"
df_people.loc[1, "email"] =  "iremSçakır@email.com"
df_people.loc[2, "email"] =  "cerenIcukurlu@email.com"

df_people
# Out:
# C:\Users\monstr\AppData\Local\Temp\ipykernel_9908\4251753290.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'emrecakir@gmail.com' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_people.loc[0, "email"] =  "emrecakir@gmail.com"
#           first     last                    email  new
# 4        Halise  Çukurlu                        3  NaN
# 3         Hacer    Çakır                        3  NaN
# 2  Ceren İlayda  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 1  İrem Süheyla  ÇUKURLU     iremSçakır@email.com  NaN
# 0          Emre    ÇAKIR      emrecakir@gmail.com  NaN

# %%
def update_first(first):
    return first.upper()

df_people['first'] = df_people['first'].apply(update_first)

df_people
# Out:
#           first     last                    email  new
# 4        HALISE  Çukurlu                        3  NaN
# 3         HACER    Çakır                        3  NaN
# 2  CEREN İLAYDA  ÇUKURLU  cerenIcukurlu@email.com  NaN
# 1  İREM SÜHEYLA  ÇUKURLU     iremSçakır@email.com  NaN
# 0          EMRE    ÇAKIR      emrecakir@gmail.com  NaN

# %%
df_people['email'] = df_people['email'].apply(update_first)
df_people
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 df_people['email'] = df_people['email'].apply(update_first)
#       2 df_people
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:4757, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
# -> 4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
#    4764     ).apply()
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[185], line 2, in update_first(first)
#       1 def update_first(first):
# ----> 2     return first.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
df_people.loc[0] = df_people.loc[0].str.title()
df_people.loc[1] = df_people.loc[1].str.title()
df_people.loc[2] = df_people.loc[2].str.title()

df_people
# Out:
#           first     last                    email  new
# 4        HALISE  Çukurlu                        3  NaN
# 3         HACER    Çakır                        3  NaN
# 2  Ceren İlayda  Çukurlu  Cerenicukurlu@Email.Com  NaN
# 1  İrem Süheyla  Çukurlu     Iremsçakır@Email.Com  NaN
# 0          Emre    Çakir      Emrecakir@Gmail.Com  NaN

# %%
df_people.loc[0, "email"] =  "emrecakir@gmail.com"
df_people.loc[1, "email"] =  "iremSçakır@email.com"
df_people.loc[2, "email"] =  "cerenIcukurlu@email.com"
df_people
# Out:
#           first     last                    email  new
# 4        HALISE  Çukurlu                        3  NaN
# 3         HACER    Çakır                        3  NaN
# 2  Ceren İlayda  Çukurlu  cerenIcukurlu@email.com  NaN
# 1  İrem Süheyla  Çukurlu     iremSçakır@email.com  NaN
# 0          Emre    Çakir      emrecakir@gmail.com  NaN

# %% [markdown]
# #### **🗣️ map() Metodu**

# %%
df_people
# Out:
#           first     last                    email  new
# 4        HALISE  Çukurlu                        3  NaN
# 3         HACER    Çakır                        3  NaN
# 2  Ceren İlayda  Çukurlu  cerenIcukurlu@email.com  NaN
# 1  İrem Süheyla  Çukurlu     iremSçakır@email.com  NaN
# 0          Emre    Çakir      emrecakir@gmail.com  NaN

# %%
df_people.map(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 df_people.map(len)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:10120, in DataFrame.map(self, func, na_action, **kwargs)
#   10117 def infer(x):
#   10118     return x._map_values(func, na_action=na_action)
# > 10120 return self.apply(infer).__finalize__(self, "map")
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:965, in FrameApply.apply_standard(self)
#     964 def apply_standard(self):
# --> 965     results, res_index = self.apply_series_generator()
#     967     # wrap results
#     968     return self.wrap_results(results, res_index)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:981, in FrameApply.apply_series_generator(self)
#     978 with option_context("mode.chained_assignment", None):
#     979     for i, v in enumerate(series_gen):
#     980         # ignore SettingWithCopy here in case the user mutates
# --> 981         results[i] = self.func(v, *self.args, **self.kwargs)
#     982         if isinstance(results[i], ABCSeries):
#     983             # If we have a view on v, we need to make a copy because
#     984             #  series_generator will swap out the underlying data
#     985             results[i] = results[i].copy(deep=False)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:10118, in DataFrame.map.<locals>.infer(x)
#   10117 def infer(x):
# > 10118     return x._map_values(func, na_action=na_action)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'int' has no len()

# %%
df_people
# Out:
#           first     last                    email  new
# 4        HALISE  Çukurlu                        3  NaN
# 3         HACER    Çakır                        3  NaN
# 2  Ceren İlayda  Çukurlu  cerenIcukurlu@email.com  NaN
# 1  İrem Süheyla  Çukurlu     iremSçakır@email.com  NaN
# 0          Emre    Çakir      emrecakir@gmail.com  NaN

# %%
df_people.map(str.upper)        # ana tabloya uygulamadık
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 df_people.map(str.upper)        # ana tabloya uygulamadık
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:10120, in DataFrame.map(self, func, na_action, **kwargs)
#   10117 def infer(x):
#   10118     return x._map_values(func, na_action=na_action)
# > 10120 return self.apply(infer).__finalize__(self, "map")
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
#   10025     self,
#   10026     func=func,
#    (...)
#   10032     kwargs=kwargs,
#   10033 )
# > 10034 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:965, in FrameApply.apply_standard(self)
#     964 def apply_standard(self):
# --> 965     results, res_index = self.apply_series_generator()
#     967     # wrap results
#     968     return self.wrap_results(results, res_index)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:981, in FrameApply.apply_series_generator(self)
#     978 with option_context("mode.chained_assignment", None):
#     979     for i, v in enumerate(series_gen):
#     980         # ignore SettingWithCopy here in case the user mutates
# --> 981         results[i] = self.func(v, *self.args, **self.kwargs)
#     982         if isinstance(results[i], ABCSeries):
#     983             # If we have a view on v, we need to make a copy because
#     984             #  series_generator will swap out the underlying data
#     985             results[i] = results[i].copy(deep=False)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:10118, in DataFrame.map.<locals>.infer(x)
#   10117 def infer(x):
# > 10118     return x._map_values(func, na_action=na_action)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\monstr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# TypeError: descriptor 'upper' for 'str' objects doesn't apply to a 'int' object

# %%
df_people['first'] = df_people['first'].map({'Emre':'Erkin','İRem Süheyla':'Ozan', 'Ceren İLayda':'Emre'})
df_people
# Out:
#    first     last                    email  new
# 4    NaN  Çukurlu                        3  NaN
# 3    NaN    Çakır                        3  NaN
# 2    NaN  Çukurlu  cerenIcukurlu@email.com  NaN
# 1    NaN  Çukurlu     iremSçakır@email.com  NaN
# 0  Erkin    Çakir      emrecakir@gmail.com  NaN

# %%
df_people.loc[0,'last'] = "Çakır"
df_people.loc[1,'last'] = "Çakır"
df_people.loc[2,'last'] = "Çakır"
df_people
# Out:
#    first     last                    email  new
# 4    NaN  Çukurlu                        3  NaN
# 3    NaN    Çakır                        3  NaN
# 2    NaN    Çakır  cerenIcukurlu@email.com  NaN
# 1    NaN    Çakır     iremSçakır@email.com  NaN
# 0  Erkin    Çakır      emrecakir@gmail.com  NaN

# %% [markdown]
# #### **🗣️ replace() Metodu**

# %%
df_people['first'] = df_people['first'].replace({'Erkin':'Emre','Ozan':'Emre'})

df_people
# Out:
#   first     last                    email  new
# 4   NaN  Çukurlu                        3  NaN
# 3   NaN    Çakır                        3  NaN
# 2   NaN    Çakır  cerenIcukurlu@email.com  NaN
# 1   NaN    Çakır     iremSçakır@email.com  NaN
# 0  Emre    Çakır      emrecakir@gmail.com  NaN

# %%
df_people['last'] = df_people['last'].replace({'Çakır':'ÇAKIR'})
df_people
# Out:
#   first     last                    email  new
# 4   NaN  Çukurlu                        3  NaN
# 3   NaN    ÇAKIR                        3  NaN
# 2   NaN    ÇAKIR  cerenIcukurlu@email.com  NaN
# 1   NaN    ÇAKIR     iremSçakır@email.com  NaN
# 0  Emre    ÇAKIR      emrecakir@gmail.com  NaN

# %% [markdown]
# #### **🗣️ info()**

# %%
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 4 to 0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   1 non-null      object
#  1   last    5 non-null      object
#  2   email   5 non-null      object
#  3   new     0 non-null      object
# dtypes: object(4)
# memory usage: 372.0+ bytes

# %% [markdown]
# #### **🗣️ shape**

# %% [markdown]
#     Bu metod bir data frame in yani tablonun kaç tane satırdan ve kaç tane sütundan oluştuğunu söyler:
#
#     ÖR: (x, y) --> x : number of rows, y : number of columns

# %%
df_people.shape         # bu tablo 3 row ve 3 column'dan oluşmaktadır
# Out:
# (5, 4)

# %%
df_survey.shape         # bu tablo 88.883 row ve 84 column'dan oluşmaktadır
# Out:
# (88883, 84)

# %%
df_schema.shape         # bu tablo 85 row ve 1 column'dan oluşmaktadır
# Out:
# (85, 1)

# %% [markdown]
# #### **🗣️ columns**

# %% [markdown]
#     Bir tabloya ait column başlıklarını bir liste halinde bize sunar

# %%
df_people.columns
# Out:
# Index(['first', 'last', 'email', 'new'], dtype='object')

# %%
df_survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df_schema.columns
# Out:
# Index(['QuestionText'], dtype='object')

# %% [markdown]
# #### **🗣️ head()**

# %% [markdown]
#     Tablolarımız görselleştirirkne kaç tane row gözükmesini isitoyrsak onu head() komutunun içine yazarak belirleyebiliriz.

# %%
df_people.head(2)           # bu kod, tablomuzun 2 satırının gözükmesini sağlar
# Out:
#   first     last                  email          new
# 0  Emre    Çakır    emrecakir@gmail.com    emrecakir
# 1  İrem  Çukurlu  iremcukurlu@email.com  iremcukurlu

# %%
df_survey.head(5)           # bu kod, tablomuzun 5 satırının gözükmesini sağlar
# Out:
#                                                    MainBranch Hobbyist  ...  \
# Respondent                                                              ...
# 1                      I am a student who is learning to code      Yes  ...
# 2                      I am a student who is learning to code       No  ...
# 3           I am not primarily a developer, but I write co...      Yes  ...
# 4                              I am a developer by profession       No  ...
# 5                              I am a developer by profession      Yes  ...
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
#
# [5 rows x 84 columns]

# %%
df_schema.head(3)           # bu kod, tablomuzun 3 satırının gözükmesini sağlar
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?

# %% [markdown]
# #### **🗣️ sum()**
